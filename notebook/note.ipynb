# %%
import requests

# %%
response = requests.get("https://docs.langchain.com/llms.txt")
text = response.text
text_lines = text.splitlines()
text_lines
# Out:
# ['# Docs by LangChain',
#  '',
#  '## Docs',
#  '',
#  '- [null](https://docs.langchain.com/index.md)',
#  '- [Connect an authentication provider](https://docs.langchain.com/langsmith/add-auth-server.md)',
#  '- [Human-in-the-loop using server API](https://docs.langchain.com/langsmith/add-human-in-the-loop.md)',
#  '- [Add metadata and tags to traces](https://docs.langchain.com/langsmith/add-metadata-tags.md)',
#  '- [Overview](https://docs.langchain.com/langsmith/administration-overview.md)',
#  '- [Set up Agent Auth (Beta)](https://docs.langchain.com/langsmith/agent-auth.md): Enable secure access from agents to any system using OAuth 2.0 credentials with Agent Auth.',
#  '- [Agent Builder](https://docs.langchain.com/langsmith/agent-builder.md)',
#  '- [Agent Builder setup](https://docs.langchain.com/langsmith/agent-builder-setup.md): Add required workspace secrets for models and tools used by Agent Builder.',
#  '- [Supported tools](https://docs.langchain.com/langsmith/agent-builder-tools.md)',
#  '- [Alerts in LangSmith](https://docs.langchain.com/langsmith/alerts.md)',
#  '- [Configure webhook notifications for LangSmith alerts](https://docs.langchain.com/langsmith/alerts-webhook.md)',
#  '- [Analyze an experiment](https://docs.langchain.com/langsmith/analyze-an-experiment.md)',
#  '- [Custom instrumentation](https://docs.langchain.com/langsmith/annotate-code.md)',
#  '- [Annotate traces and runs inline](https://docs.langchain.com/langsmith/annotate-traces-inline.md)',
#  '- [Use annotation queues](https://docs.langchain.com/langsmith/annotation-queues.md)',
#  '- [Control plane API reference for LangSmith Deployment](https://docs.langchain.com/langsmith/api-ref-control-plane.md)',
#  '- [App development in LangSmith Deployment](https://docs.langchain.com/langsmith/app-development.md)',
#  '- [Application structure](https://docs.langchain.com/langsmith/application-structure.md)',
#  '- [Assistants](https://docs.langchain.com/langsmith/assistants.md)',
#  '- [Log user feedback using the SDK](https://docs.langchain.com/langsmith/attach-user-feedback.md)',
#  '- [How to audit evaluator scores](https://docs.langchain.com/langsmith/audit-evaluator-scores.md)',
#  '- [Authentication & access control](https://docs.langchain.com/langsmith/auth.md)',
#  '- [Authentication methods](https://docs.langchain.com/langsmith/authentication-methods.md)',
#  '- [How to integrate LangGraph with AutoGen, CrewAI, and other frameworks](https://docs.langchain.com/langsmith/autogen-integration.md)',
#  '- [How to kick off background runs](https://docs.langchain.com/langsmith/background-run.md)',
#  '- [Manage billing in your account](https://docs.langchain.com/langsmith/billing.md)',
#  '- [Automatically run evaluators on experiments](https://docs.langchain.com/langsmith/bind-evaluator-to-dataset.md)',
#  '- [Implement a CI/CD pipeline using LangSmith Deployments and Evaluation](https://docs.langchain.com/langsmith/cicd-pipeline-example.md)',
#  '- [LangGraph CLI](https://docs.langchain.com/langsmith/cli.md)',
#  '- [Cloud](https://docs.langchain.com/langsmith/cloud.md)',
#  '- [How to define a code evaluator](https://docs.langchain.com/langsmith/code-evaluator.md)',
#  '- [Beta LangSmith Collector-Proxy](https://docs.langchain.com/langsmith/collector-proxy.md)',
#  '- [How to compare experiment results](https://docs.langchain.com/langsmith/compare-experiment-results.md)',
#  '- [Compare traces](https://docs.langchain.com/langsmith/compare-traces.md)',
#  '- [LangSmith components](https://docs.langchain.com/langsmith/components.md)',
#  '- [Composite evaluators](https://docs.langchain.com/langsmith/composite-evaluators.md)',
#  '- [Configurable headers](https://docs.langchain.com/langsmith/configurable-headers.md)',
#  '- [Manage assistants](https://docs.langchain.com/langsmith/configuration-cloud.md)',
#  '- [How to add TTLs to your application](https://docs.langchain.com/langsmith/configure-ttl.md)',
#  '- [LangSmith control plane](https://docs.langchain.com/langsmith/control-plane.md)',
#  '- [Create a prompt](https://docs.langchain.com/langsmith/create-a-prompt.md)',
#  '- [Create an account and API key](https://docs.langchain.com/langsmith/create-account-api-key.md)',
#  '- [How to improve your evaluator with few-shot examples](https://docs.langchain.com/langsmith/create-few-shot-evaluators.md)',
#  '- [Use cron jobs](https://docs.langchain.com/langsmith/cron-jobs.md)',
#  '- [Add custom authentication](https://docs.langchain.com/langsmith/custom-auth.md)',
#  '- [How to customize the Dockerfile](https://docs.langchain.com/langsmith/custom-docker.md)',
#  '- [Connect to a custom model](https://docs.langchain.com/langsmith/custom-endpoint.md)',
#  '- [How to add custom lifespan events](https://docs.langchain.com/langsmith/custom-lifespan.md)',
#  '- [How to add custom middleware](https://docs.langchain.com/langsmith/custom-middleware.md)',
#  '- [Connect to an OpenAI compliant model provider/proxy](https://docs.langchain.com/langsmith/custom-openai-compliant-model.md)',
#  '- [Custom output rendering](https://docs.langchain.com/langsmith/custom-output-rendering.md)',
#  '- [How to add custom routes](https://docs.langchain.com/langsmith/custom-routes.md)',
#  '- [Monitor projects with dashboards](https://docs.langchain.com/langsmith/dashboards.md)',
#  '- [Bulk Exporting Trace Data](https://docs.langchain.com/langsmith/data-export.md)',
#  '- [LangSmith data plane](https://docs.langchain.com/langsmith/data-plane.md)',
#  '- [Data purging for compliance](https://docs.langchain.com/langsmith/data-purging-compliance.md)',
#  '- [Data storage and privacy](https://docs.langchain.com/langsmith/data-storage-and-privacy.md)',
#  '- [Dataset prebuilt JSON schema types](https://docs.langchain.com/langsmith/dataset-json-types.md)',
#  '- [Dataset transformations](https://docs.langchain.com/langsmith/dataset-transformations.md)',
#  '- [How to define a target function to evaluate](https://docs.langchain.com/langsmith/define-target-function.md)',
#  '- [Set up hybrid LangSmith](https://docs.langchain.com/langsmith/deploy-hybrid.md)',
#  '- [Enable LangSmith Deployment](https://docs.langchain.com/langsmith/deploy-self-hosted-full-platform.md)',
#  '- [Self-host standalone servers](https://docs.langchain.com/langsmith/deploy-standalone-server.md)',
#  '- [LangSmith on Cloud](https://docs.langchain.com/langsmith/deploy-to-cloud.md)',
#  '- [Deploy with control plane](https://docs.langchain.com/langsmith/deploy-with-control-plane.md)',
#  '- [Deploy your app to Cloud](https://docs.langchain.com/langsmith/deployment-quickstart.md)',
#  '- [LangSmith Deployment](https://docs.langchain.com/langsmith/deployments.md)',
#  '- [Implement distributed tracing](https://docs.langchain.com/langsmith/distributed-tracing.md)',
#  '- [Self-host LangSmith with Docker](https://docs.langchain.com/langsmith/docker.md)',
#  '- [Double texting](https://docs.langchain.com/langsmith/double-texting.md)',
#  '- [Enqueue concurrent](https://docs.langchain.com/langsmith/enqueue-concurrent.md)',
#  '- [Environment variables](https://docs.langchain.com/langsmith/env-var.md)',
#  '- [Evaluate a chatbot](https://docs.langchain.com/langsmith/evaluate-chatbot-tutorial.md)',
#  '- [Evaluate a complex agent](https://docs.langchain.com/langsmith/evaluate-complex-agent.md)',
#  '- [How to evaluate an existing experiment (Python only)](https://docs.langchain.com/langsmith/evaluate-existing-experiment.md)',
#  '- [How to evaluate a graph](https://docs.langchain.com/langsmith/evaluate-graph.md)',
#  '- [How to evaluate an LLM application](https://docs.langchain.com/langsmith/evaluate-llm-application.md)',
#  "- [How to evaluate an application's intermediate steps](https://docs.langchain.com/langsmith/evaluate-on-intermediate-steps.md)",
#  '- [How to run a pairwise evaluation](https://docs.langchain.com/langsmith/evaluate-pairwise.md)',
#  '- [Evaluate a RAG application](https://docs.langchain.com/langsmith/evaluate-rag-tutorial.md)',
#  '- [Run an evaluation with multimodal content](https://docs.langchain.com/langsmith/evaluate-with-attachments.md)',
#  '- [LangSmith Evaluations](https://docs.langchain.com/langsmith/evaluation.md)',
#  '- [Application-specific evaluation approaches](https://docs.langchain.com/langsmith/evaluation-approaches.md)',
#  '- [How to run an evaluation asynchronously](https://docs.langchain.com/langsmith/evaluation-async.md)',
#  '- [Evaluation Concepts](https://docs.langchain.com/langsmith/evaluation-concepts.md)',
#  '- [Evaluation quickstart](https://docs.langchain.com/langsmith/evaluation-quickstart.md)',
#  '- [Example data format](https://docs.langchain.com/langsmith/example-data-format.md)',
#  '- [Export LangSmith telemetry to your observability backend](https://docs.langchain.com/langsmith/export-backend.md)',
#  '- [Query traces (SDK)](https://docs.langchain.com/langsmith/export-traces.md)',
#  '- [Frequently asked questions](https://docs.langchain.com/langsmith/faq.md)',
#  '- [Feedback data format](https://docs.langchain.com/langsmith/feedback-data-format.md)',
#  '- [How to fetch performance metrics for an experiment](https://docs.langchain.com/langsmith/fetch-perf-metrics-experiment.md)',
#  '- [How to filter experiments in the UI](https://docs.langchain.com/langsmith/filter-experiments-ui.md)',
#  '- [Filter traces](https://docs.langchain.com/langsmith/filter-traces-in-application.md)',
#  '- [How to implement generative user interfaces with LangGraph](https://docs.langchain.com/langsmith/generative-ui-react.md)',
#  '- [Rebuild graph at runtime](https://docs.langchain.com/langsmith/graph-rebuild.md)',
#  '- [LangSmith docs](https://docs.langchain.com/langsmith/home.md)',
#  '- [Time travel using the server API](https://docs.langchain.com/langsmith/human-in-the-loop-time-travel.md)',
#  '- [Hybrid](https://docs.langchain.com/langsmith/hybrid.md)',
#  '- [Improve LLM-as-judge evaluators using human feedback](https://docs.langchain.com/langsmith/improve-judge-evaluator-feedback.md)',
#  '- [Dynamic few shot example selection](https://docs.langchain.com/langsmith/index-datasets-for-dynamic-few-shot-example-selection.md)',
#  '- [Discover errors and usage patterns with the Insights Agent](https://docs.langchain.com/langsmith/insights.md)',
#  '- [Integrations](https://docs.langchain.com/langsmith/integrations.md)',
#  '- [Interrupt concurrent](https://docs.langchain.com/langsmith/interrupt-concurrent.md)',
#  '- [Self-host LangSmith on Kubernetes](https://docs.langchain.com/langsmith/kubernetes.md)',
#  '- [How to evaluate a runnable](https://docs.langchain.com/langsmith/langchain-runnable.md)',
#  '- [LangGraph JS/TS SDK](https://docs.langchain.com/langsmith/langgraph-js-ts-sdk.md)',
#  '- [LangGraph Python SDK](https://docs.langchain.com/langsmith/langgraph-python-sdk.md)',
#  '- [LangGraph Server](https://docs.langchain.com/langsmith/langgraph-server.md)',
#  '- [LangGraph Server changelog](https://docs.langchain.com/langsmith/langgraph-server-changelog.md)',
#  '- [Configure your collector for LangSmith telemetry](https://docs.langchain.com/langsmith/langsmith-collector.md)',
#  '- [LangSmith-managed ClickHouse](https://docs.langchain.com/langsmith/langsmith-managed-clickhouse.md)',
#  '- [How to define an LLM-as-a-judge evaluator](https://docs.langchain.com/langsmith/llm-as-judge.md)',
#  '- [How to run an evaluation locally (Python only)](https://docs.langchain.com/langsmith/local.md)',
#  '- [Run a LangGraph app locally](https://docs.langchain.com/langsmith/local-server.md)',
#  '- [Log LLM calls](https://docs.langchain.com/langsmith/log-llm-trace.md)',
#  '- [Log multimodal traces](https://docs.langchain.com/langsmith/log-multimodal-traces.md)',
#  '- [Log retriever traces](https://docs.langchain.com/langsmith/log-retriever-trace.md)',
#  '- [Log traces to a specific project](https://docs.langchain.com/langsmith/log-traces-to-project.md)',
#  '- [Manage datasets](https://docs.langchain.com/langsmith/manage-datasets.md)',
#  '- [Create and manage datasets in the UI](https://docs.langchain.com/langsmith/manage-datasets-in-application.md)',
#  '- [How to create and manage datasets programmatically](https://docs.langchain.com/langsmith/manage-datasets-programmatically.md)',
#  '- [Manage your organization using the API](https://docs.langchain.com/langsmith/manage-organization-by-api.md)',
#  '- [Manage prompts](https://docs.langchain.com/langsmith/manage-prompts.md)',
#  '- [Manage prompts programmatically](https://docs.langchain.com/langsmith/manage-prompts-programmatically.md)',
#  '- [Configure prompt settings](https://docs.langchain.com/langsmith/managing-model-configurations.md)',
#  '- [Prevent logging of sensitive data in traces](https://docs.langchain.com/langsmith/mask-inputs-outputs.md)',
#  '- [How to return categorical vs numerical metrics](https://docs.langchain.com/langsmith/metric-type.md)',
#  '- [Monorepo support](https://docs.langchain.com/langsmith/monorepo-support.md)',
#  '- [How to simulate multi-turn interactions](https://docs.langchain.com/langsmith/multi-turn-simulation.md)',
#  '- [Include multimodal content in a prompt](https://docs.langchain.com/langsmith/multimodal-content.md)',
#  '- [Test multi-turn conversations](https://docs.langchain.com/langsmith/multiple-messages.md)',
#  '- [How to return multiple scores in one evaluator](https://docs.langchain.com/langsmith/multiple-scores.md)',
#  '- [Troubleshoot trace nesting](https://docs.langchain.com/langsmith/nest-traces.md)',
#  '- [LangSmith Observability](https://docs.langchain.com/langsmith/observability.md)',
#  '- [Observability concepts](https://docs.langchain.com/langsmith/observability-concepts.md)',
#  '- [Trace a RAG application tutorial](https://docs.langchain.com/langsmith/observability-llm-tutorial.md)',
#  '- [Tracing quickstart](https://docs.langchain.com/langsmith/observability-quickstart.md)',
#  '- [Deploy an observability stack for your LangSmith deployment](https://docs.langchain.com/langsmith/observability-stack.md)',
#  '- [Observability in Studio](https://docs.langchain.com/langsmith/observability-studio.md)',
#  '- [Set up online evaluators](https://docs.langchain.com/langsmith/online-evaluations.md)',
#  '- [Document API authentication in OpenAPI](https://docs.langchain.com/langsmith/openapi-security.md)',
#  '- [Optimize a classifier](https://docs.langchain.com/langsmith/optimize-classifier.md)',
#  '- [View server logs for a trace](https://docs.langchain.com/langsmith/platform-logs.md)',
#  '- [Set up LangSmith](https://docs.langchain.com/langsmith/platform-setup.md)',
#  '- [How to use prebuilt evaluators](https://docs.langchain.com/langsmith/prebuilt-evaluators.md)',
#  '- [Frequently Asked Questions](https://docs.langchain.com/langsmith/pricing-faq.md)',
#  '- [Pricing plans](https://docs.langchain.com/langsmith/pricing-plans.md)',
#  '- [How to sync prompts with GitHub](https://docs.langchain.com/langsmith/prompt-commit.md)',
#  '- [Prompt engineering](https://docs.langchain.com/langsmith/prompt-engineering.md)',
#  '- [Prompt engineering concepts](https://docs.langchain.com/langsmith/prompt-engineering-concepts.md)',
#  '- [Prompt engineering quickstart](https://docs.langchain.com/langsmith/prompt-engineering-quickstart.md)',
#  '- [How to run evaluations with pytest (beta)](https://docs.langchain.com/langsmith/pytest.md)',
#  '- [Get started with Studio](https://docs.langchain.com/langsmith/quick-start-studio.md)',
#  '- [How to handle model rate limits](https://docs.langchain.com/langsmith/rate-limiting.md)',
#  '- [Regions FAQ](https://docs.langchain.com/langsmith/regions-faq.md)',
#  '- [Reject Concurrent](https://docs.langchain.com/langsmith/reject-concurrent.md)',
#  '- [Release versions](https://docs.langchain.com/langsmith/release-versions.md)',
#  '- [RemoteGraph](https://docs.langchain.com/langsmith/remote-graph.md)',
#  '- [How to evaluate with repetitions](https://docs.langchain.com/langsmith/repetition.md)',
#  '- [Make conversations private](https://docs.langchain.com/langsmith/resource-auth.md)',
#  '- [Rollback Concurrent](https://docs.langchain.com/langsmith/rollback-concurrent.md)',
#  '- [Set up automation rules](https://docs.langchain.com/langsmith/rules.md)',
#  '- [Run backtests on a new version of an agent](https://docs.langchain.com/langsmith/run-backtests-new-agent.md)',
#  '- [Run (span) data format](https://docs.langchain.com/langsmith/run-data-format.md)',
#  '- [How to use the REST API](https://docs.langchain.com/langsmith/run-evals-api-only.md)',
#  '- [Run an evaluation from the prompt playground](https://docs.langchain.com/langsmith/run-evaluation-from-prompt-playground.md)',
#  '- [How to run multiple agents on the same thread](https://docs.langchain.com/langsmith/same-thread.md)',
#  '- [Set a sampling rate for traces](https://docs.langchain.com/langsmith/sample-traces.md)',
#  '- [Scalability & resilience](https://docs.langchain.com/langsmith/scalability-and-resilience.md)',
#  '- [Delete workspaces](https://docs.langchain.com/langsmith/script-delete-a-workspace.md)',
#  '- [Delete organizations](https://docs.langchain.com/langsmith/script-delete-an-organization.md)',
#  '- [Delete traces](https://docs.langchain.com/langsmith/script-delete-traces.md)',
#  '- [Generate ClickHouse stats](https://docs.langchain.com/langsmith/script-generate-clickhouse-stats.md)',
#  '- [Generate query stats](https://docs.langchain.com/langsmith/script-generate-query-stats.md)',
#  '- [Run support queries against ClickHouse](https://docs.langchain.com/langsmith/script-running-ch-support-queries.md)',
#  '- [Run support queries against PostgreSQL](https://docs.langchain.com/langsmith/script-running-pg-support-queries.md)',
#  '- [Basic authentication with email and password](https://docs.langchain.com/langsmith/self-host-basic-auth.md)',
#  '- [Enable blob storage](https://docs.langchain.com/langsmith/self-host-blob-storage.md)',
#  '- [Configure custom TLS certificates](https://docs.langchain.com/langsmith/self-host-custom-tls-certificates.md)',
#  '- [Egress for subscription metrics and operational metadata](https://docs.langchain.com/langsmith/self-host-egress.md)',
#  '- [Connect to an external ClickHouse database](https://docs.langchain.com/langsmith/self-host-external-clickhouse.md)',
#  '- [Connect to an external PostgreSQL database](https://docs.langchain.com/langsmith/self-host-external-postgres.md)',
#  '- [Connect to an external Redis database](https://docs.langchain.com/langsmith/self-host-external-redis.md)',
#  '- [Create an Ingress for installations (Kubernetes)](https://docs.langchain.com/langsmith/self-host-ingress.md)',
#  '- [Mirror images for your LangSmith installation](https://docs.langchain.com/langsmith/self-host-mirroring-images.md)',
#  '- [View trace counts across your organization](https://docs.langchain.com/langsmith/self-host-organization-charts.md)',
#  '- [Use environment variables for model providers](https://docs.langchain.com/langsmith/self-host-playground-environment-settings.md)',
#  '- [Configure LangSmith for scale](https://docs.langchain.com/langsmith/self-host-scale.md)',
#  '- [Set up SSO with OAuth2.0 and OIDC](https://docs.langchain.com/langsmith/self-host-sso.md)',
#  '- [Enable TTL and data retention](https://docs.langchain.com/langsmith/self-host-ttl.md)',
#  '- [Upgrade an installation](https://docs.langchain.com/langsmith/self-host-upgrades.md)',
#  '- [Interact with your self-hosted instance of LangSmith](https://docs.langchain.com/langsmith/self-host-usage.md)',
#  '- [Customize user management](https://docs.langchain.com/langsmith/self-host-user-management.md)',
#  '- [Use an existing secret for your installation (Kubernetes)](https://docs.langchain.com/langsmith/self-host-using-an-existing-secret.md)',
#  '- [Self-hosted LangSmith](https://docs.langchain.com/langsmith/self-hosted.md)',
#  '- [How to add semantic search to your agent deployment](https://docs.langchain.com/langsmith/semantic-search.md)',
#  '- [A2A endpoint in LangGraph Server](https://docs.langchain.com/langsmith/server-a2a.md)',
#  '- [LangGraph Server API reference for LangSmith Deployment](https://docs.langchain.com/langsmith/server-api-ref.md)',
#  '- [MCP endpoint in LangGraph Server](https://docs.langchain.com/langsmith/server-mcp.md)',
#  '- [Trace JS functions in serverless environments](https://docs.langchain.com/langsmith/serverless-environments.md)',
#  '- [Set up a workspace](https://docs.langchain.com/langsmith/set-up-a-workspace.md)',
#  '- [Set up custom authentication](https://docs.langchain.com/langsmith/set-up-custom-auth.md)',
#  '- [Set up feedback criteria](https://docs.langchain.com/langsmith/set-up-feedback-criteria.md)',
#  '- [Set up resource tags](https://docs.langchain.com/langsmith/set-up-resource-tags.md)',
#  '- [How to set up an application with requirements.txt](https://docs.langchain.com/langsmith/setup-app-requirements-txt.md)',
#  '- [How to set up a JavaScript application](https://docs.langchain.com/langsmith/setup-javascript.md)',
#  '- [How to set up an application with pyproject.toml](https://docs.langchain.com/langsmith/setup-pyproject.md)',
#  '- [Share or unshare a trace publicly](https://docs.langchain.com/langsmith/share-trace.md)',
#  '- [LangSmith API reference](https://docs.langchain.com/langsmith/smith-api-ref.md)',
#  '- [LangSmith JS/TS SDK](https://docs.langchain.com/langsmith/smith-js-ts-sdk.md)',
#  '- [LangSmith Python SDK](https://docs.langchain.com/langsmith/smith-python-sdk.md)',
#  '- [Stateless runs](https://docs.langchain.com/langsmith/stateless-runs.md)',
#  '- [Streaming API](https://docs.langchain.com/langsmith/streaming.md)',
#  '- [LangSmith Studio](https://docs.langchain.com/langsmith/studio.md)',
#  '- [How to define a summary evaluator](https://docs.langchain.com/langsmith/summary.md)',
#  '- [Test a ReAct agent with Pytest/Vitest and LangSmith](https://docs.langchain.com/langsmith/test-react-agent-pytest.md)',
#  '- [Configure threads](https://docs.langchain.com/langsmith/threads.md)',
#  '- [Trace with Anthropic](https://docs.langchain.com/langsmith/trace-anthropic.md)',
#  '- [Trace Claude Agent SDK](https://docs.langchain.com/langsmith/trace-claude-agent-sdk.md)',
#  '- [Trace Claude Code](https://docs.langchain.com/langsmith/trace-claude-code.md)',
#  '- [Trace generator functions](https://docs.langchain.com/langsmith/trace-generator-functions.md)',
#  '- [Trace with OpenAI](https://docs.langchain.com/langsmith/trace-openai.md)',
#  '- [Trace query syntax](https://docs.langchain.com/langsmith/trace-query-syntax.md)',
#  '- [Trace with API](https://docs.langchain.com/langsmith/trace-with-api.md)',
#  '- [Trace with AutoGen](https://docs.langchain.com/langsmith/trace-with-autogen.md)',
#  '- [Trace with CrewAI](https://docs.langchain.com/langsmith/trace-with-crewai.md)',
#  '- [Trace with Google ADK](https://docs.langchain.com/langsmith/trace-with-google-adk.md)',
#  '- [Trace with Instructor](https://docs.langchain.com/langsmith/trace-with-instructor.md)',
#  '- [Trace with LangChain (Python and JS/TS)](https://docs.langchain.com/langsmith/trace-with-langchain.md)',
#  '- [Trace with LangGraph](https://docs.langchain.com/langsmith/trace-with-langgraph.md)',
#  '- [Trace with OpenAI Agents SDK](https://docs.langchain.com/langsmith/trace-with-openai-agents-sdk.md)',
#  '- [Trace with OpenTelemetry](https://docs.langchain.com/langsmith/trace-with-opentelemetry.md)',
#  '- [Trace with Semantic Kernel](https://docs.langchain.com/langsmith/trace-with-semantic-kernel.md)',
#  '- [Trace with the Vercel AI SDK (JS/TS only)](https://docs.langchain.com/langsmith/trace-with-vercel-ai-sdk.md)',
#  '- [Trace without setting environment variables](https://docs.langchain.com/langsmith/trace-without-env-vars.md)',
#  '- [How to evaluate your agent with trajectory evaluations](https://docs.langchain.com/langsmith/trajectory-evals.md)',
#  '- [Troubleshooting](https://docs.langchain.com/langsmith/troubleshooting.md)',
#  '- [Studio troubleshooting](https://docs.langchain.com/langsmith/troubleshooting-studio.md)',
#  '- [Troubleshoot variable caching](https://docs.langchain.com/langsmith/troubleshooting-variable-caching.md)',
#  '- [How to upload experiments run outside of LangSmith with the REST API](https://docs.langchain.com/langsmith/upload-existing-experiments.md)',
#  '- [Upload files with traces](https://docs.langchain.com/langsmith/upload-files-with-traces.md)',
#  '- [How to interact with a deployment using RemoteGraph](https://docs.langchain.com/langsmith/use-remote-graph.md)',
#  '- [How to integrate LangGraph into your React application](https://docs.langchain.com/langsmith/use-stream-react.md)',
#  '- [How to use Studio](https://docs.langchain.com/langsmith/use-studio.md)',
#  '- [Use threads](https://docs.langchain.com/langsmith/use-threads.md)',
#  '- [Use tools in a prompt](https://docs.langchain.com/langsmith/use-tools.md)',
#  '- [Use webhooks](https://docs.langchain.com/langsmith/use-webhooks.md)',
#  '- [User management](https://docs.langchain.com/langsmith/user-management.md)',
#  '- [How to run evaluations with Vitest/Jest (beta)](https://docs.langchain.com/langsmith/vitest-jest.md)',
#  '- [Configure webhook notifications for rules](https://docs.langchain.com/langsmith/webhooks.md)',
#  '- [Write your prompt with AI](https://docs.langchain.com/langsmith/write-prompt-with-ai.md)',
#  '- [Error troubleshooting](https://docs.langchain.com/oss/javascript/common-errors.md)',
#  '- [Context overview](https://docs.langchain.com/oss/javascript/concepts/context.md)',
#  '- [Memory overview](https://docs.langchain.com/oss/javascript/concepts/memory.md)',
#  '- [Contributing to code](https://docs.langchain.com/oss/javascript/contributing/code.md)',
#  '- [Co-marketing](https://docs.langchain.com/oss/javascript/contributing/comarketing.md)',
#  '- [Contributing to documentation](https://docs.langchain.com/oss/javascript/contributing/documentation.md)',
#  '- [Implement a LangChain integration](https://docs.langchain.com/oss/javascript/contributing/implement-langchain.md)',
#  '- [Implement a LangGraph integration](https://docs.langchain.com/oss/javascript/contributing/implement-langgraph.md)',
#  '- [Contributing integrations](https://docs.langchain.com/oss/javascript/contributing/integrations-langchain.md)',
#  '- [Contributing integrations](https://docs.langchain.com/oss/javascript/contributing/integrations-langgraph.md)',
#  '- [Contributing](https://docs.langchain.com/oss/javascript/contributing/overview.md)',
#  '- [Publish an integration](https://docs.langchain.com/oss/javascript/contributing/publish-langchain.md)',
#  '- [Publish an integration](https://docs.langchain.com/oss/javascript/contributing/publish-langgraph.md)',
#  '- [Using standard tests](https://docs.langchain.com/oss/javascript/contributing/standard-tests-langchain.md)',
#  '- [Using standard tests](https://docs.langchain.com/oss/javascript/contributing/standard-tests-langgraph.md)',
#  '- [Callbacks](https://docs.langchain.com/oss/javascript/integrations/callbacks/index.md)',
#  '- [ChatAnthropic](https://docs.langchain.com/oss/javascript/integrations/chat/anthropic.md)',
#  '- [AzureChatOpenAI](https://docs.langchain.com/oss/javascript/integrations/chat/azure.md)',
#  '- [BedrockChat](https://docs.langchain.com/oss/javascript/integrations/chat/bedrock.md)',
#  '- [ChatGoogleGenerativeAI](https://docs.langchain.com/oss/javascript/integrations/chat/google_generative_ai.md)',
#  '- [Chat models](https://docs.langchain.com/oss/javascript/integrations/chat/index.md)',
#  '- [ChatOpenAI](https://docs.langchain.com/oss/javascript/integrations/chat/openai.md)',
#  '- [null](https://docs.langchain.com/oss/javascript/integrations/document_loaders/index.md)',
#  '- [Document transformers](https://docs.langchain.com/oss/javascript/integrations/document_transformers/index.md)',
#  '- [Model caches](https://docs.langchain.com/oss/javascript/integrations/llm_caching/index.md)',
#  '- [LLMs](https://docs.langchain.com/oss/javascript/integrations/llms/index.md)',
#  '- [All integrations](https://docs.langchain.com/oss/javascript/integrations/providers/all_providers.md)',
#  '- [Overview](https://docs.langchain.com/oss/javascript/integrations/providers/anthropic.md)',
#  '- [Overview](https://docs.langchain.com/oss/javascript/integrations/providers/aws.md)',
#  '- [Overview](https://docs.langchain.com/oss/javascript/integrations/providers/google.md)',
#  '- [Overview](https://docs.langchain.com/oss/javascript/integrations/providers/microsoft.md)',
#  '- [Overview](https://docs.langchain.com/oss/javascript/integrations/providers/openai.md)',
#  '- [Integration Packages](https://docs.langchain.com/oss/javascript/integrations/providers/overview.md)',
#  '- [Retrievers](https://docs.langchain.com/oss/javascript/integrations/retrievers/index.md)',
#  '- [Text splitters](https://docs.langchain.com/oss/javascript/integrations/splitters/index.md)',
#  '- [Key-value stores](https://docs.langchain.com/oss/javascript/integrations/stores/index.md)',
#  '- [AzureOpenAIEmbeddings](https://docs.langchain.com/oss/javascript/integrations/text_embedding/azure_openai.md)',
#  '- [BedrockEmbeddings](https://docs.langchain.com/oss/javascript/integrations/text_embedding/bedrock.md)',
#  '- [GoogleGenerativeAIEmbeddings](https://docs.langchain.com/oss/javascript/integrations/text_embedding/google_generativeai.md)',
#  '- [Embedding models](https://docs.langchain.com/oss/javascript/integrations/text_embedding/index.md)',
#  '- [OpenAIEmbeddings](https://docs.langchain.com/oss/javascript/integrations/text_embedding/openai.md)',
#  '- [Tools and Toolkits](https://docs.langchain.com/oss/javascript/integrations/tools/index.md)',
#  '- [Vector stores](https://docs.langchain.com/oss/javascript/integrations/vectorstores/index.md)',
#  '- [LangChain Academy](https://docs.langchain.com/oss/javascript/langchain/academy.md)',
#  '- [Agents](https://docs.langchain.com/oss/javascript/langchain/agents.md)',
#  '- [Context engineering in agents](https://docs.langchain.com/oss/javascript/langchain/context-engineering.md)',
#  '- [Deploy](https://docs.langchain.com/oss/javascript/langchain/deploy.md)',
#  '- [INVALID_PROMPT_INPUT](https://docs.langchain.com/oss/javascript/langchain/errors/INVALID_PROMPT_INPUT.md)',
#  '- [INVALID_TOOL_RESULTS](https://docs.langchain.com/oss/javascript/langchain/errors/INVALID_TOOL_RESULTS.md)',
#  '- [MESSAGE_COERCION_FAILURE](https://docs.langchain.com/oss/javascript/langchain/errors/MESSAGE_COERCION_FAILURE.md)',
#  '- [MODEL_AUTHENTICATION](https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_AUTHENTICATION.md)',
#  '- [MODEL_NOT_FOUND](https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_NOT_FOUND.md)',
#  '- [MODEL_RATE_LIMIT](https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_RATE_LIMIT.md)',
#  '- [OUTPUT_PARSING_FAILURE](https://docs.langchain.com/oss/javascript/langchain/errors/OUTPUT_PARSING_FAILURE.md)',
#  '- [Guardrails](https://docs.langchain.com/oss/javascript/langchain/guardrails.md): Implement safety checks and content filtering for your agents',
#  '- [Human-in-the-loop](https://docs.langchain.com/oss/javascript/langchain/human-in-the-loop.md)',
#  '- [Install LangChain](https://docs.langchain.com/oss/javascript/langchain/install.md)',
#  '- [Build a semantic search engine with LangChain](https://docs.langchain.com/oss/javascript/langchain/knowledge-base.md)',
#  '- [Long-term memory](https://docs.langchain.com/oss/javascript/langchain/long-term-memory.md)',
#  '- [Model Context Protocol (MCP)](https://docs.langchain.com/oss/javascript/langchain/mcp.md)',
#  '- [Messages](https://docs.langchain.com/oss/javascript/langchain/messages.md)',
#  '- [Middleware](https://docs.langchain.com/oss/javascript/langchain/middleware.md): Control and customize agent execution at every step',
#  '- [Models](https://docs.langchain.com/oss/javascript/langchain/models.md)',
#  '- [Multi-agent](https://docs.langchain.com/oss/javascript/langchain/multi-agent.md)',
#  '- [Observability](https://docs.langchain.com/oss/javascript/langchain/observability.md)',
#  '- [LangChain overview](https://docs.langchain.com/oss/javascript/langchain/overview.md)',
#  '- [Philosophy](https://docs.langchain.com/oss/javascript/langchain/philosophy.md): LangChain exists to be the easiest place to start building with LLMs, while also being flexible and production-ready.',
#  '- [Quickstart](https://docs.langchain.com/oss/javascript/langchain/quickstart.md)',
#  '- [Build a RAG agent with LangChain](https://docs.langchain.com/oss/javascript/langchain/rag.md)',
#  '- [Retrieval](https://docs.langchain.com/oss/javascript/langchain/retrieval.md)',
#  '- [Runtime](https://docs.langchain.com/oss/javascript/langchain/runtime.md)',
#  '- [Short-term memory](https://docs.langchain.com/oss/javascript/langchain/short-term-memory.md)',
#  '- [Build a SQL agent](https://docs.langchain.com/oss/javascript/langchain/sql-agent.md)',
#  '- [Streaming](https://docs.langchain.com/oss/javascript/langchain/streaming.md)',
#  '- [Structured output](https://docs.langchain.com/oss/javascript/langchain/structured-output.md)',
#  '- [Studio](https://docs.langchain.com/oss/javascript/langchain/studio.md)',
#  '- [Build a supervisor agent](https://docs.langchain.com/oss/javascript/langchain/supervisor.md)',
#  '- [Test](https://docs.langchain.com/oss/javascript/langchain/test.md)',
#  '- [Tools](https://docs.langchain.com/oss/javascript/langchain/tools.md)',
#  '- [Agent Chat UI](https://docs.langchain.com/oss/javascript/langchain/ui.md)',
#  '- [Memory](https://docs.langchain.com/oss/javascript/langgraph/add-memory.md)',
#  '- [Build a custom RAG agent](https://docs.langchain.com/oss/javascript/langgraph/agentic-rag.md)',
#  '- [Application structure](https://docs.langchain.com/oss/javascript/langgraph/application-structure.md)',
#  '- [Case studies](https://docs.langchain.com/oss/javascript/langgraph/case-studies.md)',
#  '- [Deploy](https://docs.langchain.com/oss/javascript/langgraph/deploy.md)',
#  '- [Durable execution](https://docs.langchain.com/oss/javascript/langgraph/durable-execution.md)',
#  '- [GRAPH_RECURSION_LIMIT](https://docs.langchain.com/oss/javascript/langgraph/errors/GRAPH_RECURSION_LIMIT.md)',
#  '- [INVALID_CHAT_HISTORY](https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_CHAT_HISTORY.md)',
#  '- [INVALID_CONCURRENT_GRAPH_UPDATE](https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE.md)',
#  '- [INVALID_GRAPH_NODE_RETURN_VALUE](https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_GRAPH_NODE_RETURN_VALUE.md)',
#  '- [MISSING_CHECKPOINTER](https://docs.langchain.com/oss/javascript/langgraph/errors/MISSING_CHECKPOINTER.md)',
#  '- [MULTIPLE_SUBGRAPHS](https://docs.langchain.com/oss/javascript/langgraph/errors/MULTIPLE_SUBGRAPHS.md)',
#  '- [Functional API overview](https://docs.langchain.com/oss/javascript/langgraph/functional-api.md)',
#  '- [Graph API overview](https://docs.langchain.com/oss/javascript/langgraph/graph-api.md)',
#  '- [Install LangGraph](https://docs.langchain.com/oss/javascript/langgraph/install.md)',
#  '- [Interrupts](https://docs.langchain.com/oss/javascript/langgraph/interrupts.md)',
#  '- [Run a local server](https://docs.langchain.com/oss/javascript/langgraph/local-server.md)',
#  '- [Observability](https://docs.langchain.com/oss/javascript/langgraph/observability.md)',
#  '- [LangGraph overview](https://docs.langchain.com/oss/javascript/langgraph/overview.md)',
#  '- [Persistence](https://docs.langchain.com/oss/javascript/langgraph/persistence.md)',
#  '- [LangGraph runtime](https://docs.langchain.com/oss/javascript/langgraph/pregel.md)',
#  '- [Quickstart](https://docs.langchain.com/oss/javascript/langgraph/quickstart.md)',
#  '- [Streaming](https://docs.langchain.com/oss/javascript/langgraph/streaming.md)',
#  '- [Studio](https://docs.langchain.com/oss/javascript/langgraph/studio.md)',
#  '- [Test](https://docs.langchain.com/oss/javascript/langgraph/test.md)',
#  '- [Thinking in LangGraph](https://docs.langchain.com/oss/javascript/langgraph/thinking-in-langgraph.md): Learn how to think about building agents with LangGraph by breaking down a customer support email agent into discrete steps',
#  '- [Agent Chat UI](https://docs.langchain.com/oss/javascript/langgraph/ui.md)',
#  '- [Use the functional API](https://docs.langchain.com/oss/javascript/langgraph/use-functional-api.md)',
#  '- [Use the graph API](https://docs.langchain.com/oss/javascript/langgraph/use-graph-api.md)',
#  '- [Subgraphs](https://docs.langchain.com/oss/javascript/langgraph/use-subgraphs.md)',
#  '- [Use time-travel](https://docs.langchain.com/oss/javascript/langgraph/use-time-travel.md)',
#  '- [Workflows and agents](https://docs.langchain.com/oss/javascript/langgraph/workflows-agents.md)',
#  '- [Learn](https://docs.langchain.com/oss/javascript/learn.md): Tutorials, conceptual guides, and resources to help you get started.',
#  '- [LangChain v1 migration guide](https://docs.langchain.com/oss/javascript/migrate/langchain-v1.md)',
#  '- [LangGraph v1 migration guide](https://docs.langchain.com/oss/javascript/migrate/langgraph-v1.md)',
#  '- [LangChain SDK](https://docs.langchain.com/oss/javascript/reference/langchain-javascript.md)',
#  '- [LangGraph SDK](https://docs.langchain.com/oss/javascript/reference/langgraph-javascript.md)',
#  '- [Reference](https://docs.langchain.com/oss/javascript/reference/overview.md)',
#  '- [Release policy](https://docs.langchain.com/oss/javascript/release-policy.md)',
#  "- [What's new in v1](https://docs.langchain.com/oss/javascript/releases/langchain-v1.md)",
#  "- [What's new in v1](https://docs.langchain.com/oss/javascript/releases/langgraph-v1.md)",
#  '- [Security policy](https://docs.langchain.com/oss/javascript/security-policy.md)',
#  '- [Versioning](https://docs.langchain.com/oss/javascript/versioning.md)',
#  '- [Error troubleshooting](https://docs.langchain.com/oss/python/common-errors.md)',
#  '- [Context overview](https://docs.langchain.com/oss/python/concepts/context.md)',
#  '- [Memory overview](https://docs.langchain.com/oss/python/concepts/memory.md)',
#  '- [Contributing to code](https://docs.langchain.com/oss/python/contributing/code.md)',
#  '- [Co-marketing](https://docs.langchain.com/oss/python/contributing/comarketing.md)',
#  '- [Contributing to documentation](https://docs.langchain.com/oss/python/contributing/documentation.md)',
#  '- [Implement a LangChain integration](https://docs.langchain.com/oss/python/contributing/implement-langchain.md)',
#  '- [Implement a LangGraph integration](https://docs.langchain.com/oss/python/contributing/implement-langgraph.md)',
#  '- [Contributing integrations](https://docs.langchain.com/oss/python/contributing/integrations-langchain.md)',
#  '- [Contributing integrations](https://docs.langchain.com/oss/python/contributing/integrations-langgraph.md)',
#  '- [Contributing](https://docs.langchain.com/oss/python/contributing/overview.md)',
#  '- [Publish an integration](https://docs.langchain.com/oss/python/contributing/publish-langchain.md)',
#  '- [Publish an integration](https://docs.langchain.com/oss/python/contributing/publish-langgraph.md)',
#  '- [Using standard tests](https://docs.langchain.com/oss/python/contributing/standard-tests-langchain.md)',
#  '- [Using standard tests](https://docs.langchain.com/oss/python/contributing/standard-tests-langgraph.md)',
#  '- [Backends](https://docs.langchain.com/oss/python/deepagents/backends.md): Choose and configure filesystem backends for deep agents. You can specify routes to different backends, implement virtual filesystems, and enforce policies.',
#  '- [Customize Deep Agents](https://docs.langchain.com/oss/python/deepagents/customization.md): Learn how to customize deep agents with system prompts, tools, subagents, and more',
#  '- [Agent harness capabilities](https://docs.langchain.com/oss/python/deepagents/harness.md)',
#  '- [Human-in-the-loop](https://docs.langchain.com/oss/python/deepagents/human-in-the-loop.md): Learn how to configure human approval for sensitive tool operations',
#  '- [Long-term memory](https://docs.langchain.com/oss/python/deepagents/long-term-memory.md): Learn how to extend deep agents with persistent memory across threads',
#  '- [Deep Agents overview](https://docs.langchain.com/oss/python/deepagents/overview.md): Build agents that can plan, use subagents, and leverage file systems for complex tasks',
#  '- [Quickstart](https://docs.langchain.com/oss/python/deepagents/quickstart.md): Build your first deep agent in minutes',
#  '- [Subagents](https://docs.langchain.com/oss/python/deepagents/subagents.md): Learn how to use subagents to delegate work and keep context clean',
#  '- [Chat models](https://docs.langchain.com/oss/python/integrations/chat/index.md)',
#  '- [null](https://docs.langchain.com/oss/python/integrations/document_loaders/index.md)',
#  '- [All integration providers](https://docs.langchain.com/oss/python/integrations/providers/all_providers.md)',
#  '- [Anthropic (Claude)](https://docs.langchain.com/oss/python/integrations/providers/anthropic.md)',
#  '- [AWS (Amazon)](https://docs.langchain.com/oss/python/integrations/providers/aws.md)',
#  '- [Google](https://docs.langchain.com/oss/python/integrations/providers/google.md)',
#  '- [Hugging Face](https://docs.langchain.com/oss/python/integrations/providers/huggingface.md)',
#  '- [Microsoft](https://docs.langchain.com/oss/python/integrations/providers/microsoft.md)',
#  '- [Ollama](https://docs.langchain.com/oss/python/integrations/providers/ollama.md)',
#  '- [OpenAI](https://docs.langchain.com/oss/python/integrations/providers/openai.md)',
#  '- [Integration packages](https://docs.langchain.com/oss/python/integrations/providers/overview.md)',
#  '- [Retrievers](https://docs.langchain.com/oss/python/integrations/retrievers/index.md)',
#  '- [Text splitters](https://docs.langchain.com/oss/python/integrations/splitters/index.md)',
#  '- [Key-value stores](https://docs.langchain.com/oss/python/integrations/stores/index.md)',
#  '- [Embedding models](https://docs.langchain.com/oss/python/integrations/text_embedding/index.md)',
#  '- [Tools and toolkits](https://docs.langchain.com/oss/python/integrations/tools/index.md)',
#  '- [Vector stores](https://docs.langchain.com/oss/python/integrations/vectorstores/index.md)',
#  '- [LangChain Academy](https://docs.langchain.com/oss/python/langchain/academy.md)',
#  '- [Agents](https://docs.langchain.com/oss/python/langchain/agents.md)',
#  '- [Context engineering in agents](https://docs.langchain.com/oss/python/langchain/context-engineering.md)',
#  '- [Deploy](https://docs.langchain.com/oss/python/langchain/deploy.md)',
#  '- [INVALID_PROMPT_INPUT](https://docs.langchain.com/oss/python/langchain/errors/INVALID_PROMPT_INPUT.md)',
#  '- [INVALID_TOOL_RESULTS](https://docs.langchain.com/oss/python/langchain/errors/INVALID_TOOL_RESULTS.md)',
#  '- [MESSAGE_COERCION_FAILURE](https://docs.langchain.com/oss/python/langchain/errors/MESSAGE_COERCION_FAILURE.md)',
#  '- [MODEL_AUTHENTICATION](https://docs.langchain.com/oss/python/langchain/errors/MODEL_AUTHENTICATION.md)',
#  '- [MODEL_NOT_FOUND](https://docs.langchain.com/oss/python/langchain/errors/MODEL_NOT_FOUND.md)',
#  '- [MODEL_RATE_LIMIT](https://docs.langchain.com/oss/python/langchain/errors/MODEL_RATE_LIMIT.md)',
#  '- [OUTPUT_PARSING_FAILURE](https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE.md)',
#  '- [Guardrails](https://docs.langchain.com/oss/python/langchain/guardrails.md): Implement safety checks and content filtering for your agents',
#  '- [Human-in-the-loop](https://docs.langchain.com/oss/python/langchain/human-in-the-loop.md)',
#  '- [Install LangChain](https://docs.langchain.com/oss/python/langchain/install.md)',
#  '- [Build a semantic search engine with LangChain](https://docs.langchain.com/oss/python/langchain/knowledge-base.md)',
#  '- [Long-term memory](https://docs.langchain.com/oss/python/langchain/long-term-memory.md)',
#  '- [Model Context Protocol (MCP)](https://docs.langchain.com/oss/python/langchain/mcp.md)',
#  '- [Messages](https://docs.langchain.com/oss/python/langchain/messages.md)',
#  '- [Middleware](https://docs.langchain.com/oss/python/langchain/middleware.md): Control and customize agent execution at every step',
#  '- [Models](https://docs.langchain.com/oss/python/langchain/models.md)',
#  '- [Multi-agent](https://docs.langchain.com/oss/python/langchain/multi-agent.md)',
#  '- [Observability](https://docs.langchain.com/oss/python/langchain/observability.md)',
#  '- [LangChain overview](https://docs.langchain.com/oss/python/langchain/overview.md)',
#  '- [Philosophy](https://docs.langchain.com/oss/python/langchain/philosophy.md): LangChain exists to be the easiest place to start building with LLMs, while also being flexible and production-ready.',
#  '- [Quickstart](https://docs.langchain.com/oss/python/langchain/quickstart.md)',
#  '- [Build a RAG agent with LangChain](https://docs.langchain.com/oss/python/langchain/rag.md)',
#  '- [Retrieval](https://docs.langchain.com/oss/python/langchain/retrieval.md)',
#  '- [Runtime](https://docs.langchain.com/oss/python/langchain/runtime.md)',
#  '- [Short-term memory](https://docs.langchain.com/oss/python/langchain/short-term-memory.md)',
#  '- [Build a SQL agent](https://docs.langchain.com/oss/python/langchain/sql-agent.md)',
#  '- [Streaming](https://docs.langchain.com/oss/python/langchain/streaming.md)',
#  '- [Structured output](https://docs.langchain.com/oss/python/langchain/structured-output.md)',
#  '- [Studio](https://docs.langchain.com/oss/python/langchain/studio.md)',
#  '- [Build a supervisor agent](https://docs.langchain.com/oss/python/langchain/supervisor.md)',
#  '- [Test](https://docs.langchain.com/oss/python/langchain/test.md)',
#  '- [Tools](https://docs.langchain.com/oss/python/langchain/tools.md)',
#  '- [Agent Chat UI](https://docs.langchain.com/oss/python/langchain/ui.md)',
#  '- [Memory](https://docs.langchain.com/oss/python/langgraph/add-memory.md)',
#  '- [Build a custom RAG agent](https://docs.langchain.com/oss/python/langgraph/agentic-rag.md)',
#  '- [Application structure](https://docs.langchain.com/oss/python/langgraph/application-structure.md)',
#  '- [Case studies](https://docs.langchain.com/oss/python/langgraph/case-studies.md)',
#  '- [Deploy](https://docs.langchain.com/oss/python/langgraph/deploy.md)',
#  '- [Durable execution](https://docs.langchain.com/oss/python/langgraph/durable-execution.md)',
#  '- [GRAPH_RECURSION_LIMIT](https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT.md)',
#  '- [INVALID_CHAT_HISTORY](https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CHAT_HISTORY.md)',
#  '- [INVALID_CONCURRENT_GRAPH_UPDATE](https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE.md)',
#  '- [INVALID_GRAPH_NODE_RETURN_VALUE](https://docs.langchain.com/oss/python/langgraph/errors/INVALID_GRAPH_NODE_RETURN_VALUE.md)',
#  '- [MISSING_CHECKPOINTER](https://docs.langchain.com/oss/python/langgraph/errors/MISSING_CHECKPOINTER.md)',
#  '- [MULTIPLE_SUBGRAPHS](https://docs.langchain.com/oss/python/langgraph/errors/MULTIPLE_SUBGRAPHS.md)',
#  '- [Functional API overview](https://docs.langchain.com/oss/python/langgraph/functional-api.md)',
#  '- [Graph API overview](https://docs.langchain.com/oss/python/langgraph/graph-api.md)',
#  '- [Install LangGraph](https://docs.langchain.com/oss/python/langgraph/install.md)',
#  '- [Interrupts](https://docs.langchain.com/oss/python/langgraph/interrupts.md)',
#  '- [Run a local server](https://docs.langchain.com/oss/python/langgraph/local-server.md)',
#  '- [Observability](https://docs.langchain.com/oss/python/langgraph/observability.md)',
#  '- [LangGraph overview](https://docs.langchain.com/oss/python/langgraph/overview.md)',
#  '- [Persistence](https://docs.langchain.com/oss/python/langgraph/persistence.md)',
#  '- [LangGraph runtime](https://docs.langchain.com/oss/python/langgraph/pregel.md)',
#  '- [Quickstart](https://docs.langchain.com/oss/python/langgraph/quickstart.md)',
#  '- [Build a custom SQL agent](https://docs.langchain.com/oss/python/langgraph/sql-agent.md)',
#  '- [Streaming](https://docs.langchain.com/oss/python/langgraph/streaming.md)',
#  '- [Studio](https://docs.langchain.com/oss/python/langgraph/studio.md)',
#  '- [Test](https://docs.langchain.com/oss/python/langgraph/test.md)',
#  '- [Thinking in LangGraph](https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph.md): Learn how to think about building agents with LangGraph by breaking down a customer support email agent into discrete steps',
#  '- [Agent Chat UI](https://docs.langchain.com/oss/python/langgraph/ui.md)',
#  '- [Use the functional API](https://docs.langchain.com/oss/python/langgraph/use-functional-api.md)',
#  '- [Use the graph API](https://docs.langchain.com/oss/python/langgraph/use-graph-api.md)',
#  '- [Subgraphs](https://docs.langchain.com/oss/python/langgraph/use-subgraphs.md)',
#  '- [Use time-travel](https://docs.langchain.com/oss/python/langgraph/use-time-travel.md)',
#  '- [Workflows and agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents.md)',
#  '- [Learn](https://docs.langchain.com/oss/python/learn.md): Tutorials, conceptual guides, and resources to help you get started.',
#  '- [LangChain v1 migration guide](https://docs.langchain.com/oss/python/migrate/langchain-v1.md)',
#  '- [LangGraph v1 migration guide](https://docs.langchain.com/oss/python/migrate/langgraph-v1.md)',
#  '- [Deep Agents](https://docs.langchain.com/oss/python/reference/deepagents-python.md)',
#  '- [Integrations](https://docs.langchain.com/oss/python/reference/integrations-python.md)',
#  '- [LangChain SDK](https://docs.langchain.com/oss/python/reference/langchain-python.md)',
#  '- [LangGraph SDK](https://docs.langchain.com/oss/python/reference/langgraph-python.md)',
#  '- [Reference](https://docs.langchain.com/oss/python/reference/overview.md)',
#  '- [Release policy](https://docs.langchain.com/oss/python/release-policy.md)',
#  "- [What's new in v1](https://docs.langchain.com/oss/python/releases/langchain-v1.md)",
#  "- [What's new in v1](https://docs.langchain.com/oss/python/releases/langgraph-v1.md)",
#  '- [Security policy](https://docs.langchain.com/oss/python/security-policy.md)',
#  '- [Versioning](https://docs.langchain.com/oss/python/versioning.md)']

# %%
len(text_lines)
# Out:
# 502

# %% [markdown]
# #### Extracting topics and urls

# %%
import re
topics = re.findall(r"\[([^\[\]]+)\]", text)
topics
# Out:
# ['null',
#  'Connect an authentication provider',
#  'Human-in-the-loop using server API',
#  'Add metadata and tags to traces',
#  'Overview',
#  'Set up Agent Auth (Beta)',
#  'Agent Builder',
#  'Agent Builder setup',
#  'Supported tools',
#  'Alerts in LangSmith',
#  'Configure webhook notifications for LangSmith alerts',
#  'Analyze an experiment',
#  'Custom instrumentation',
#  'Annotate traces and runs inline',
#  'Use annotation queues',
#  'Control plane API reference for LangSmith Deployment',
#  'App development in LangSmith Deployment',
#  'Application structure',
#  'Assistants',
#  'Log user feedback using the SDK',
#  'How to audit evaluator scores',
#  'Authentication & access control',
#  'Authentication methods',
#  'How to integrate LangGraph with AutoGen, CrewAI, and other frameworks',
#  'How to kick off background runs',
#  'Manage billing in your account',
#  'Automatically run evaluators on experiments',
#  'Implement a CI/CD pipeline using LangSmith Deployments and Evaluation',
#  'LangGraph CLI',
#  'Cloud',
#  'How to define a code evaluator',
#  'Beta LangSmith Collector-Proxy',
#  'How to compare experiment results',
#  'Compare traces',
#  'LangSmith components',
#  'Composite evaluators',
#  'Configurable headers',
#  'Manage assistants',
#  'How to add TTLs to your application',
#  'LangSmith control plane',
#  'Create a prompt',
#  'Create an account and API key',
#  'How to improve your evaluator with few-shot examples',
#  'Use cron jobs',
#  'Add custom authentication',
#  'How to customize the Dockerfile',
#  'Connect to a custom model',
#  'How to add custom lifespan events',
#  'How to add custom middleware',
#  'Connect to an OpenAI compliant model provider/proxy',
#  'Custom output rendering',
#  'How to add custom routes',
#  'Monitor projects with dashboards',
#  'Bulk Exporting Trace Data',
#  'LangSmith data plane',
#  'Data purging for compliance',
#  'Data storage and privacy',
#  'Dataset prebuilt JSON schema types',
#  'Dataset transformations',
#  'How to define a target function to evaluate',
#  'Set up hybrid LangSmith',
#  'Enable LangSmith Deployment',
#  'Self-host standalone servers',
#  'LangSmith on Cloud',
#  'Deploy with control plane',
#  'Deploy your app to Cloud',
#  'LangSmith Deployment',
#  'Implement distributed tracing',
#  'Self-host LangSmith with Docker',
#  'Double texting',
#  'Enqueue concurrent',
#  'Environment variables',
#  'Evaluate a chatbot',
#  'Evaluate a complex agent',
#  'How to evaluate an existing experiment (Python only)',
#  'How to evaluate a graph',
#  'How to evaluate an LLM application',
#  "How to evaluate an application's intermediate steps",
#  'How to run a pairwise evaluation',
#  'Evaluate a RAG application',
#  'Run an evaluation with multimodal content',
#  'LangSmith Evaluations',
#  'Application-specific evaluation approaches',
#  'How to run an evaluation asynchronously',
#  'Evaluation Concepts',
#  'Evaluation quickstart',
#  'Example data format',
#  'Export LangSmith telemetry to your observability backend',
#  'Query traces (SDK)',
#  'Frequently asked questions',
#  'Feedback data format',
#  'How to fetch performance metrics for an experiment',
#  'How to filter experiments in the UI',
#  'Filter traces',
#  'How to implement generative user interfaces with LangGraph',
#  'Rebuild graph at runtime',
#  'LangSmith docs',
#  'Time travel using the server API',
#  'Hybrid',
#  'Improve LLM-as-judge evaluators using human feedback',
#  'Dynamic few shot example selection',
#  'Discover errors and usage patterns with the Insights Agent',
#  'Integrations',
#  'Interrupt concurrent',
#  'Self-host LangSmith on Kubernetes',
#  'How to evaluate a runnable',
#  'LangGraph JS/TS SDK',
#  'LangGraph Python SDK',
#  'LangGraph Server',
#  'LangGraph Server changelog',
#  'Configure your collector for LangSmith telemetry',
#  'LangSmith-managed ClickHouse',
#  'How to define an LLM-as-a-judge evaluator',
#  'How to run an evaluation locally (Python only)',
#  'Run a LangGraph app locally',
#  'Log LLM calls',
#  'Log multimodal traces',
#  'Log retriever traces',
#  'Log traces to a specific project',
#  'Manage datasets',
#  'Create and manage datasets in the UI',
#  'How to create and manage datasets programmatically',
#  'Manage your organization using the API',
#  'Manage prompts',
#  'Manage prompts programmatically',
#  'Configure prompt settings',
#  'Prevent logging of sensitive data in traces',
#  'How to return categorical vs numerical metrics',
#  'Monorepo support',
#  'How to simulate multi-turn interactions',
#  'Include multimodal content in a prompt',
#  'Test multi-turn conversations',
#  'How to return multiple scores in one evaluator',
#  'Troubleshoot trace nesting',
#  'LangSmith Observability',
#  'Observability concepts',
#  'Trace a RAG application tutorial',
#  'Tracing quickstart',
#  'Deploy an observability stack for your LangSmith deployment',
#  'Observability in Studio',
#  'Set up online evaluators',
#  'Document API authentication in OpenAPI',
#  'Optimize a classifier',
#  'View server logs for a trace',
#  'Set up LangSmith',
#  'How to use prebuilt evaluators',
#  'Frequently Asked Questions',
#  'Pricing plans',
#  'How to sync prompts with GitHub',
#  'Prompt engineering',
#  'Prompt engineering concepts',
#  'Prompt engineering quickstart',
#  'How to run evaluations with pytest (beta)',
#  'Get started with Studio',
#  'How to handle model rate limits',
#  'Regions FAQ',
#  'Reject Concurrent',
#  'Release versions',
#  'RemoteGraph',
#  'How to evaluate with repetitions',
#  'Make conversations private',
#  'Rollback Concurrent',
#  'Set up automation rules',
#  'Run backtests on a new version of an agent',
#  'Run (span) data format',
#  'How to use the REST API',
#  'Run an evaluation from the prompt playground',
#  'How to run multiple agents on the same thread',
#  'Set a sampling rate for traces',
#  'Scalability & resilience',
#  'Delete workspaces',
#  'Delete organizations',
#  'Delete traces',
#  'Generate ClickHouse stats',
#  'Generate query stats',
#  'Run support queries against ClickHouse',
#  'Run support queries against PostgreSQL',
#  'Basic authentication with email and password',
#  'Enable blob storage',
#  'Configure custom TLS certificates',
#  'Egress for subscription metrics and operational metadata',
#  'Connect to an external ClickHouse database',
#  'Connect to an external PostgreSQL database',
#  'Connect to an external Redis database',
#  'Create an Ingress for installations (Kubernetes)',
#  'Mirror images for your LangSmith installation',
#  'View trace counts across your organization',
#  'Use environment variables for model providers',
#  'Configure LangSmith for scale',
#  'Set up SSO with OAuth2.0 and OIDC',
#  'Enable TTL and data retention',
#  'Upgrade an installation',
#  'Interact with your self-hosted instance of LangSmith',
#  'Customize user management',
#  'Use an existing secret for your installation (Kubernetes)',
#  'Self-hosted LangSmith',
#  'How to add semantic search to your agent deployment',
#  'A2A endpoint in LangGraph Server',
#  'LangGraph Server API reference for LangSmith Deployment',
#  'MCP endpoint in LangGraph Server',
#  'Trace JS functions in serverless environments',
#  'Set up a workspace',
#  'Set up custom authentication',
#  'Set up feedback criteria',
#  'Set up resource tags',
#  'How to set up an application with requirements.txt',
#  'How to set up a JavaScript application',
#  'How to set up an application with pyproject.toml',
#  'Share or unshare a trace publicly',
#  'LangSmith API reference',
#  'LangSmith JS/TS SDK',
#  'LangSmith Python SDK',
#  'Stateless runs',
#  'Streaming API',
#  'LangSmith Studio',
#  'How to define a summary evaluator',
#  'Test a ReAct agent with Pytest/Vitest and LangSmith',
#  'Configure threads',
#  'Trace with Anthropic',
#  'Trace Claude Agent SDK',
#  'Trace Claude Code',
#  'Trace generator functions',
#  'Trace with OpenAI',
#  'Trace query syntax',
#  'Trace with API',
#  'Trace with AutoGen',
#  'Trace with CrewAI',
#  'Trace with Google ADK',
#  'Trace with Instructor',
#  'Trace with LangChain (Python and JS/TS)',
#  'Trace with LangGraph',
#  'Trace with OpenAI Agents SDK',
#  'Trace with OpenTelemetry',
#  'Trace with Semantic Kernel',
#  'Trace with the Vercel AI SDK (JS/TS only)',
#  'Trace without setting environment variables',
#  'How to evaluate your agent with trajectory evaluations',
#  'Troubleshooting',
#  'Studio troubleshooting',
#  'Troubleshoot variable caching',
#  'How to upload experiments run outside of LangSmith with the REST API',
#  'Upload files with traces',
#  'How to interact with a deployment using RemoteGraph',
#  'How to integrate LangGraph into your React application',
#  'How to use Studio',
#  'Use threads',
#  'Use tools in a prompt',
#  'Use webhooks',
#  'User management',
#  'How to run evaluations with Vitest/Jest (beta)',
#  'Configure webhook notifications for rules',
#  'Write your prompt with AI',
#  'Error troubleshooting',
#  'Context overview',
#  'Memory overview',
#  'Contributing to code',
#  'Co-marketing',
#  'Contributing to documentation',
#  'Implement a LangChain integration',
#  'Implement a LangGraph integration',
#  'Contributing integrations',
#  'Contributing integrations',
#  'Contributing',
#  'Publish an integration',
#  'Publish an integration',
#  'Using standard tests',
#  'Using standard tests',
#  'Callbacks',
#  'ChatAnthropic',
#  'AzureChatOpenAI',
#  'BedrockChat',
#  'ChatGoogleGenerativeAI',
#  'Chat models',
#  'ChatOpenAI',
#  'null',
#  'Document transformers',
#  'Model caches',
#  'LLMs',
#  'All integrations',
#  'Overview',
#  'Overview',
#  'Overview',
#  'Overview',
#  'Overview',
#  'Integration Packages',
#  'Retrievers',
#  'Text splitters',
#  'Key-value stores',
#  'AzureOpenAIEmbeddings',
#  'BedrockEmbeddings',
#  'GoogleGenerativeAIEmbeddings',
#  'Embedding models',
#  'OpenAIEmbeddings',
#  'Tools and Toolkits',
#  'Vector stores',
#  'LangChain Academy',
#  'Agents',
#  'Context engineering in agents',
#  'Deploy',
#  'INVALID_PROMPT_INPUT',
#  'INVALID_TOOL_RESULTS',
#  'MESSAGE_COERCION_FAILURE',
#  'MODEL_AUTHENTICATION',
#  'MODEL_NOT_FOUND',
#  'MODEL_RATE_LIMIT',
#  'OUTPUT_PARSING_FAILURE',
#  'Guardrails',
#  'Human-in-the-loop',
#  'Install LangChain',
#  'Build a semantic search engine with LangChain',
#  'Long-term memory',
#  'Model Context Protocol (MCP)',
#  'Messages',
#  'Middleware',
#  'Models',
#  'Multi-agent',
#  'Observability',
#  'LangChain overview',
#  'Philosophy',
#  'Quickstart',
#  'Build a RAG agent with LangChain',
#  'Retrieval',
#  'Runtime',
#  'Short-term memory',
#  'Build a SQL agent',
#  'Streaming',
#  'Structured output',
#  'Studio',
#  'Build a supervisor agent',
#  'Test',
#  'Tools',
#  'Agent Chat UI',
#  'Memory',
#  'Build a custom RAG agent',
#  'Application structure',
#  'Case studies',
#  'Deploy',
#  'Durable execution',
#  'GRAPH_RECURSION_LIMIT',
#  'INVALID_CHAT_HISTORY',
#  'INVALID_CONCURRENT_GRAPH_UPDATE',
#  'INVALID_GRAPH_NODE_RETURN_VALUE',
#  'MISSING_CHECKPOINTER',
#  'MULTIPLE_SUBGRAPHS',
#  'Functional API overview',
#  'Graph API overview',
#  'Install LangGraph',
#  'Interrupts',
#  'Run a local server',
#  'Observability',
#  'LangGraph overview',
#  'Persistence',
#  'LangGraph runtime',
#  'Quickstart',
#  'Streaming',
#  'Studio',
#  'Test',
#  'Thinking in LangGraph',
#  'Agent Chat UI',
#  'Use the functional API',
#  'Use the graph API',
#  'Subgraphs',
#  'Use time-travel',
#  'Workflows and agents',
#  'Learn',
#  'LangChain v1 migration guide',
#  'LangGraph v1 migration guide',
#  'LangChain SDK',
#  'LangGraph SDK',
#  'Reference',
#  'Release policy',
#  "What's new in v1",
#  "What's new in v1",
#  'Security policy',
#  'Versioning',
#  'Error troubleshooting',
#  'Context overview',
#  'Memory overview',
#  'Contributing to code',
#  'Co-marketing',
#  'Contributing to documentation',
#  'Implement a LangChain integration',
#  'Implement a LangGraph integration',
#  'Contributing integrations',
#  'Contributing integrations',
#  'Contributing',
#  'Publish an integration',
#  'Publish an integration',
#  'Using standard tests',
#  'Using standard tests',
#  'Backends',
#  'Customize Deep Agents',
#  'Agent harness capabilities',
#  'Human-in-the-loop',
#  'Long-term memory',
#  'Deep Agents overview',
#  'Quickstart',
#  'Subagents',
#  'Chat models',
#  'null',
#  'All integration providers',
#  'Anthropic (Claude)',
#  'AWS (Amazon)',
#  'Google',
#  'Hugging Face',
#  'Microsoft',
#  'Ollama',
#  'OpenAI',
#  'Integration packages',
#  'Retrievers',
#  'Text splitters',
#  'Key-value stores',
#  'Embedding models',
#  'Tools and toolkits',
#  'Vector stores',
#  'LangChain Academy',
#  'Agents',
#  'Context engineering in agents',
#  'Deploy',
#  'INVALID_PROMPT_INPUT',
#  'INVALID_TOOL_RESULTS',
#  'MESSAGE_COERCION_FAILURE',
#  'MODEL_AUTHENTICATION',
#  'MODEL_NOT_FOUND',
#  'MODEL_RATE_LIMIT',
#  'OUTPUT_PARSING_FAILURE',
#  'Guardrails',
#  'Human-in-the-loop',
#  'Install LangChain',
#  'Build a semantic search engine with LangChain',
#  'Long-term memory',
#  'Model Context Protocol (MCP)',
#  'Messages',
#  'Middleware',
#  'Models',
#  'Multi-agent',
#  'Observability',
#  'LangChain overview',
#  'Philosophy',
#  'Quickstart',
#  'Build a RAG agent with LangChain',
#  'Retrieval',
#  'Runtime',
#  'Short-term memory',
#  'Build a SQL agent',
#  'Streaming',
#  'Structured output',
#  'Studio',
#  'Build a supervisor agent',
#  'Test',
#  'Tools',
#  'Agent Chat UI',
#  'Memory',
#  'Build a custom RAG agent',
#  'Application structure',
#  'Case studies',
#  'Deploy',
#  'Durable execution',
#  'GRAPH_RECURSION_LIMIT',
#  'INVALID_CHAT_HISTORY',
#  'INVALID_CONCURRENT_GRAPH_UPDATE',
#  'INVALID_GRAPH_NODE_RETURN_VALUE',
#  'MISSING_CHECKPOINTER',
#  'MULTIPLE_SUBGRAPHS',
#  'Functional API overview',
#  'Graph API overview',
#  'Install LangGraph',
#  'Interrupts',
#  'Run a local server',
#  'Observability',
#  'LangGraph overview',
#  'Persistence',
#  'LangGraph runtime',
#  'Quickstart',
#  'Build a custom SQL agent',
#  'Streaming',
#  'Studio',
#  'Test',
#  'Thinking in LangGraph',
#  'Agent Chat UI',
#  'Use the functional API',
#  'Use the graph API',
#  'Subgraphs',
#  'Use time-travel',
#  'Workflows and agents',
#  'Learn',
#  'LangChain v1 migration guide',
#  'LangGraph v1 migration guide',
#  'Deep Agents',
#  'Integrations',
#  'LangChain SDK',
#  'LangGraph SDK',
#  'Reference',
#  'Release policy',
#  "What's new in v1",
#  "What's new in v1",
#  'Security policy',
#  'Versioning']

# %%
urls = re.findall(r'https?://[^\s\]]+md',text)
urls
# Out:
# ['https://docs.langchain.com/index.md',
#  'https://docs.langchain.com/langsmith/add-auth-server.md',
#  'https://docs.langchain.com/langsmith/add-human-in-the-loop.md',
#  'https://docs.langchain.com/langsmith/add-metadata-tags.md',
#  'https://docs.langchain.com/langsmith/administration-overview.md',
#  'https://docs.langchain.com/langsmith/agent-auth.md',
#  'https://docs.langchain.com/langsmith/agent-builder.md',
#  'https://docs.langchain.com/langsmith/agent-builder-setup.md',
#  'https://docs.langchain.com/langsmith/agent-builder-tools.md',
#  'https://docs.langchain.com/langsmith/alerts.md',
#  'https://docs.langchain.com/langsmith/alerts-webhook.md',
#  'https://docs.langchain.com/langsmith/analyze-an-experiment.md',
#  'https://docs.langchain.com/langsmith/annotate-code.md',
#  'https://docs.langchain.com/langsmith/annotate-traces-inline.md',
#  'https://docs.langchain.com/langsmith/annotation-queues.md',
#  'https://docs.langchain.com/langsmith/api-ref-control-plane.md',
#  'https://docs.langchain.com/langsmith/app-development.md',
#  'https://docs.langchain.com/langsmith/application-structure.md',
#  'https://docs.langchain.com/langsmith/assistants.md',
#  'https://docs.langchain.com/langsmith/attach-user-feedback.md',
#  'https://docs.langchain.com/langsmith/audit-evaluator-scores.md',
#  'https://docs.langchain.com/langsmith/auth.md',
#  'https://docs.langchain.com/langsmith/authentication-methods.md',
#  'https://docs.langchain.com/langsmith/autogen-integration.md',
#  'https://docs.langchain.com/langsmith/background-run.md',
#  'https://docs.langchain.com/langsmith/billing.md',
#  'https://docs.langchain.com/langsmith/bind-evaluator-to-dataset.md',
#  'https://docs.langchain.com/langsmith/cicd-pipeline-example.md',
#  'https://docs.langchain.com/langsmith/cli.md',
#  'https://docs.langchain.com/langsmith/cloud.md',
#  'https://docs.langchain.com/langsmith/code-evaluator.md',
#  'https://docs.langchain.com/langsmith/collector-proxy.md',
#  'https://docs.langchain.com/langsmith/compare-experiment-results.md',
#  'https://docs.langchain.com/langsmith/compare-traces.md',
#  'https://docs.langchain.com/langsmith/components.md',
#  'https://docs.langchain.com/langsmith/composite-evaluators.md',
#  'https://docs.langchain.com/langsmith/configurable-headers.md',
#  'https://docs.langchain.com/langsmith/configuration-cloud.md',
#  'https://docs.langchain.com/langsmith/configure-ttl.md',
#  'https://docs.langchain.com/langsmith/control-plane.md',
#  'https://docs.langchain.com/langsmith/create-a-prompt.md',
#  'https://docs.langchain.com/langsmith/create-account-api-key.md',
#  'https://docs.langchain.com/langsmith/create-few-shot-evaluators.md',
#  'https://docs.langchain.com/langsmith/cron-jobs.md',
#  'https://docs.langchain.com/langsmith/custom-auth.md',
#  'https://docs.langchain.com/langsmith/custom-docker.md',
#  'https://docs.langchain.com/langsmith/custom-endpoint.md',
#  'https://docs.langchain.com/langsmith/custom-lifespan.md',
#  'https://docs.langchain.com/langsmith/custom-middleware.md',
#  'https://docs.langchain.com/langsmith/custom-openai-compliant-model.md',
#  'https://docs.langchain.com/langsmith/custom-output-rendering.md',
#  'https://docs.langchain.com/langsmith/custom-routes.md',
#  'https://docs.langchain.com/langsmith/dashboards.md',
#  'https://docs.langchain.com/langsmith/data-export.md',
#  'https://docs.langchain.com/langsmith/data-plane.md',
#  'https://docs.langchain.com/langsmith/data-purging-compliance.md',
#  'https://docs.langchain.com/langsmith/data-storage-and-privacy.md',
#  'https://docs.langchain.com/langsmith/dataset-json-types.md',
#  'https://docs.langchain.com/langsmith/dataset-transformations.md',
#  'https://docs.langchain.com/langsmith/define-target-function.md',
#  'https://docs.langchain.com/langsmith/deploy-hybrid.md',
#  'https://docs.langchain.com/langsmith/deploy-self-hosted-full-platform.md',
#  'https://docs.langchain.com/langsmith/deploy-standalone-server.md',
#  'https://docs.langchain.com/langsmith/deploy-to-cloud.md',
#  'https://docs.langchain.com/langsmith/deploy-with-control-plane.md',
#  'https://docs.langchain.com/langsmith/deployment-quickstart.md',
#  'https://docs.langchain.com/langsmith/deployments.md',
#  'https://docs.langchain.com/langsmith/distributed-tracing.md',
#  'https://docs.langchain.com/langsmith/docker.md',
#  'https://docs.langchain.com/langsmith/double-texting.md',
#  'https://docs.langchain.com/langsmith/enqueue-concurrent.md',
#  'https://docs.langchain.com/langsmith/env-var.md',
#  'https://docs.langchain.com/langsmith/evaluate-chatbot-tutorial.md',
#  'https://docs.langchain.com/langsmith/evaluate-complex-agent.md',
#  'https://docs.langchain.com/langsmith/evaluate-existing-experiment.md',
#  'https://docs.langchain.com/langsmith/evaluate-graph.md',
#  'https://docs.langchain.com/langsmith/evaluate-llm-application.md',
#  'https://docs.langchain.com/langsmith/evaluate-on-intermediate-steps.md',
#  'https://docs.langchain.com/langsmith/evaluate-pairwise.md',
#  'https://docs.langchain.com/langsmith/evaluate-rag-tutorial.md',
#  'https://docs.langchain.com/langsmith/evaluate-with-attachments.md',
#  'https://docs.langchain.com/langsmith/evaluation.md',
#  'https://docs.langchain.com/langsmith/evaluation-approaches.md',
#  'https://docs.langchain.com/langsmith/evaluation-async.md',
#  'https://docs.langchain.com/langsmith/evaluation-concepts.md',
#  'https://docs.langchain.com/langsmith/evaluation-quickstart.md',
#  'https://docs.langchain.com/langsmith/example-data-format.md',
#  'https://docs.langchain.com/langsmith/export-backend.md',
#  'https://docs.langchain.com/langsmith/export-traces.md',
#  'https://docs.langchain.com/langsmith/faq.md',
#  'https://docs.langchain.com/langsmith/feedback-data-format.md',
#  'https://docs.langchain.com/langsmith/fetch-perf-metrics-experiment.md',
#  'https://docs.langchain.com/langsmith/filter-experiments-ui.md',
#  'https://docs.langchain.com/langsmith/filter-traces-in-application.md',
#  'https://docs.langchain.com/langsmith/generative-ui-react.md',
#  'https://docs.langchain.com/langsmith/graph-rebuild.md',
#  'https://docs.langchain.com/langsmith/home.md',
#  'https://docs.langchain.com/langsmith/human-in-the-loop-time-travel.md',
#  'https://docs.langchain.com/langsmith/hybrid.md',
#  'https://docs.langchain.com/langsmith/improve-judge-evaluator-feedback.md',
#  'https://docs.langchain.com/langsmith/index-datasets-for-dynamic-few-shot-example-selection.md',
#  'https://docs.langchain.com/langsmith/insights.md',
#  'https://docs.langchain.com/langsmith/integrations.md',
#  'https://docs.langchain.com/langsmith/interrupt-concurrent.md',
#  'https://docs.langchain.com/langsmith/kubernetes.md',
#  'https://docs.langchain.com/langsmith/langchain-runnable.md',
#  'https://docs.langchain.com/langsmith/langgraph-js-ts-sdk.md',
#  'https://docs.langchain.com/langsmith/langgraph-python-sdk.md',
#  'https://docs.langchain.com/langsmith/langgraph-server.md',
#  'https://docs.langchain.com/langsmith/langgraph-server-changelog.md',
#  'https://docs.langchain.com/langsmith/langsmith-collector.md',
#  'https://docs.langchain.com/langsmith/langsmith-managed-clickhouse.md',
#  'https://docs.langchain.com/langsmith/llm-as-judge.md',
#  'https://docs.langchain.com/langsmith/local.md',
#  'https://docs.langchain.com/langsmith/local-server.md',
#  'https://docs.langchain.com/langsmith/log-llm-trace.md',
#  'https://docs.langchain.com/langsmith/log-multimodal-traces.md',
#  'https://docs.langchain.com/langsmith/log-retriever-trace.md',
#  'https://docs.langchain.com/langsmith/log-traces-to-project.md',
#  'https://docs.langchain.com/langsmith/manage-datasets.md',
#  'https://docs.langchain.com/langsmith/manage-datasets-in-application.md',
#  'https://docs.langchain.com/langsmith/manage-datasets-programmatically.md',
#  'https://docs.langchain.com/langsmith/manage-organization-by-api.md',
#  'https://docs.langchain.com/langsmith/manage-prompts.md',
#  'https://docs.langchain.com/langsmith/manage-prompts-programmatically.md',
#  'https://docs.langchain.com/langsmith/managing-model-configurations.md',
#  'https://docs.langchain.com/langsmith/mask-inputs-outputs.md',
#  'https://docs.langchain.com/langsmith/metric-type.md',
#  'https://docs.langchain.com/langsmith/monorepo-support.md',
#  'https://docs.langchain.com/langsmith/multi-turn-simulation.md',
#  'https://docs.langchain.com/langsmith/multimodal-content.md',
#  'https://docs.langchain.com/langsmith/multiple-messages.md',
#  'https://docs.langchain.com/langsmith/multiple-scores.md',
#  'https://docs.langchain.com/langsmith/nest-traces.md',
#  'https://docs.langchain.com/langsmith/observability.md',
#  'https://docs.langchain.com/langsmith/observability-concepts.md',
#  'https://docs.langchain.com/langsmith/observability-llm-tutorial.md',
#  'https://docs.langchain.com/langsmith/observability-quickstart.md',
#  'https://docs.langchain.com/langsmith/observability-stack.md',
#  'https://docs.langchain.com/langsmith/observability-studio.md',
#  'https://docs.langchain.com/langsmith/online-evaluations.md',
#  'https://docs.langchain.com/langsmith/openapi-security.md',
#  'https://docs.langchain.com/langsmith/optimize-classifier.md',
#  'https://docs.langchain.com/langsmith/platform-logs.md',
#  'https://docs.langchain.com/langsmith/platform-setup.md',
#  'https://docs.langchain.com/langsmith/prebuilt-evaluators.md',
#  'https://docs.langchain.com/langsmith/pricing-faq.md',
#  'https://docs.langchain.com/langsmith/pricing-plans.md',
#  'https://docs.langchain.com/langsmith/prompt-commit.md',
#  'https://docs.langchain.com/langsmith/prompt-engineering.md',
#  'https://docs.langchain.com/langsmith/prompt-engineering-concepts.md',
#  'https://docs.langchain.com/langsmith/prompt-engineering-quickstart.md',
#  'https://docs.langchain.com/langsmith/pytest.md',
#  'https://docs.langchain.com/langsmith/quick-start-studio.md',
#  'https://docs.langchain.com/langsmith/rate-limiting.md',
#  'https://docs.langchain.com/langsmith/regions-faq.md',
#  'https://docs.langchain.com/langsmith/reject-concurrent.md',
#  'https://docs.langchain.com/langsmith/release-versions.md',
#  'https://docs.langchain.com/langsmith/remote-graph.md',
#  'https://docs.langchain.com/langsmith/repetition.md',
#  'https://docs.langchain.com/langsmith/resource-auth.md',
#  'https://docs.langchain.com/langsmith/rollback-concurrent.md',
#  'https://docs.langchain.com/langsmith/rules.md',
#  'https://docs.langchain.com/langsmith/run-backtests-new-agent.md',
#  'https://docs.langchain.com/langsmith/run-data-format.md',
#  'https://docs.langchain.com/langsmith/run-evals-api-only.md',
#  'https://docs.langchain.com/langsmith/run-evaluation-from-prompt-playground.md',
#  'https://docs.langchain.com/langsmith/same-thread.md',
#  'https://docs.langchain.com/langsmith/sample-traces.md',
#  'https://docs.langchain.com/langsmith/scalability-and-resilience.md',
#  'https://docs.langchain.com/langsmith/script-delete-a-workspace.md',
#  'https://docs.langchain.com/langsmith/script-delete-an-organization.md',
#  'https://docs.langchain.com/langsmith/script-delete-traces.md',
#  'https://docs.langchain.com/langsmith/script-generate-clickhouse-stats.md',
#  'https://docs.langchain.com/langsmith/script-generate-query-stats.md',
#  'https://docs.langchain.com/langsmith/script-running-ch-support-queries.md',
#  'https://docs.langchain.com/langsmith/script-running-pg-support-queries.md',
#  'https://docs.langchain.com/langsmith/self-host-basic-auth.md',
#  'https://docs.langchain.com/langsmith/self-host-blob-storage.md',
#  'https://docs.langchain.com/langsmith/self-host-custom-tls-certificates.md',
#  'https://docs.langchain.com/langsmith/self-host-egress.md',
#  'https://docs.langchain.com/langsmith/self-host-external-clickhouse.md',
#  'https://docs.langchain.com/langsmith/self-host-external-postgres.md',
#  'https://docs.langchain.com/langsmith/self-host-external-redis.md',
#  'https://docs.langchain.com/langsmith/self-host-ingress.md',
#  'https://docs.langchain.com/langsmith/self-host-mirroring-images.md',
#  'https://docs.langchain.com/langsmith/self-host-organization-charts.md',
#  'https://docs.langchain.com/langsmith/self-host-playground-environment-settings.md',
#  'https://docs.langchain.com/langsmith/self-host-scale.md',
#  'https://docs.langchain.com/langsmith/self-host-sso.md',
#  'https://docs.langchain.com/langsmith/self-host-ttl.md',
#  'https://docs.langchain.com/langsmith/self-host-upgrades.md',
#  'https://docs.langchain.com/langsmith/self-host-usage.md',
#  'https://docs.langchain.com/langsmith/self-host-user-management.md',
#  'https://docs.langchain.com/langsmith/self-host-using-an-existing-secret.md',
#  'https://docs.langchain.com/langsmith/self-hosted.md',
#  'https://docs.langchain.com/langsmith/semantic-search.md',
#  'https://docs.langchain.com/langsmith/server-a2a.md',
#  'https://docs.langchain.com/langsmith/server-api-ref.md',
#  'https://docs.langchain.com/langsmith/server-mcp.md',
#  'https://docs.langchain.com/langsmith/serverless-environments.md',
#  'https://docs.langchain.com/langsmith/set-up-a-workspace.md',
#  'https://docs.langchain.com/langsmith/set-up-custom-auth.md',
#  'https://docs.langchain.com/langsmith/set-up-feedback-criteria.md',
#  'https://docs.langchain.com/langsmith/set-up-resource-tags.md',
#  'https://docs.langchain.com/langsmith/setup-app-requirements-txt.md',
#  'https://docs.langchain.com/langsmith/setup-javascript.md',
#  'https://docs.langchain.com/langsmith/setup-pyproject.md',
#  'https://docs.langchain.com/langsmith/share-trace.md',
#  'https://docs.langchain.com/langsmith/smith-api-ref.md',
#  'https://docs.langchain.com/langsmith/smith-js-ts-sdk.md',
#  'https://docs.langchain.com/langsmith/smith-python-sdk.md',
#  'https://docs.langchain.com/langsmith/stateless-runs.md',
#  'https://docs.langchain.com/langsmith/streaming.md',
#  'https://docs.langchain.com/langsmith/studio.md',
#  'https://docs.langchain.com/langsmith/summary.md',
#  'https://docs.langchain.com/langsmith/test-react-agent-pytest.md',
#  'https://docs.langchain.com/langsmith/threads.md',
#  'https://docs.langchain.com/langsmith/trace-anthropic.md',
#  'https://docs.langchain.com/langsmith/trace-claude-agent-sdk.md',
#  'https://docs.langchain.com/langsmith/trace-claude-code.md',
#  'https://docs.langchain.com/langsmith/trace-generator-functions.md',
#  'https://docs.langchain.com/langsmith/trace-openai.md',
#  'https://docs.langchain.com/langsmith/trace-query-syntax.md',
#  'https://docs.langchain.com/langsmith/trace-with-api.md',
#  'https://docs.langchain.com/langsmith/trace-with-autogen.md',
#  'https://docs.langchain.com/langsmith/trace-with-crewai.md',
#  'https://docs.langchain.com/langsmith/trace-with-google-adk.md',
#  'https://docs.langchain.com/langsmith/trace-with-instructor.md',
#  'https://docs.langchain.com/langsmith/trace-with-langchain.md',
#  'https://docs.langchain.com/langsmith/trace-with-langgraph.md',
#  'https://docs.langchain.com/langsmith/trace-with-openai-agents-sdk.md',
#  'https://docs.langchain.com/langsmith/trace-with-opentelemetry.md',
#  'https://docs.langchain.com/langsmith/trace-with-semantic-kernel.md',
#  'https://docs.langchain.com/langsmith/trace-with-vercel-ai-sdk.md',
#  'https://docs.langchain.com/langsmith/trace-without-env-vars.md',
#  'https://docs.langchain.com/langsmith/trajectory-evals.md',
#  'https://docs.langchain.com/langsmith/troubleshooting.md',
#  'https://docs.langchain.com/langsmith/troubleshooting-studio.md',
#  'https://docs.langchain.com/langsmith/troubleshooting-variable-caching.md',
#  'https://docs.langchain.com/langsmith/upload-existing-experiments.md',
#  'https://docs.langchain.com/langsmith/upload-files-with-traces.md',
#  'https://docs.langchain.com/langsmith/use-remote-graph.md',
#  'https://docs.langchain.com/langsmith/use-stream-react.md',
#  'https://docs.langchain.com/langsmith/use-studio.md',
#  'https://docs.langchain.com/langsmith/use-threads.md',
#  'https://docs.langchain.com/langsmith/use-tools.md',
#  'https://docs.langchain.com/langsmith/use-webhooks.md',
#  'https://docs.langchain.com/langsmith/user-management.md',
#  'https://docs.langchain.com/langsmith/vitest-jest.md',
#  'https://docs.langchain.com/langsmith/webhooks.md',
#  'https://docs.langchain.com/langsmith/write-prompt-with-ai.md',
#  'https://docs.langchain.com/oss/javascript/common-errors.md',
#  'https://docs.langchain.com/oss/javascript/concepts/context.md',
#  'https://docs.langchain.com/oss/javascript/concepts/memory.md',
#  'https://docs.langchain.com/oss/javascript/contributing/code.md',
#  'https://docs.langchain.com/oss/javascript/contributing/comarketing.md',
#  'https://docs.langchain.com/oss/javascript/contributing/documentation.md',
#  'https://docs.langchain.com/oss/javascript/contributing/implement-langchain.md',
#  'https://docs.langchain.com/oss/javascript/contributing/implement-langgraph.md',
#  'https://docs.langchain.com/oss/javascript/contributing/integrations-langchain.md',
#  'https://docs.langchain.com/oss/javascript/contributing/integrations-langgraph.md',
#  'https://docs.langchain.com/oss/javascript/contributing/overview.md',
#  'https://docs.langchain.com/oss/javascript/contributing/publish-langchain.md',
#  'https://docs.langchain.com/oss/javascript/contributing/publish-langgraph.md',
#  'https://docs.langchain.com/oss/javascript/contributing/standard-tests-langchain.md',
#  'https://docs.langchain.com/oss/javascript/contributing/standard-tests-langgraph.md',
#  'https://docs.langchain.com/oss/javascript/integrations/callbacks/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/anthropic.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/azure.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/bedrock.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/google_generative_ai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/chat/openai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/document_loaders/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/document_transformers/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/llm_caching/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/llms/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/all_providers.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/anthropic.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/aws.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/google.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/microsoft.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/openai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/providers/overview.md',
#  'https://docs.langchain.com/oss/javascript/integrations/retrievers/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/splitters/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/stores/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/text_embedding/azure_openai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/text_embedding/bedrock.md',
#  'https://docs.langchain.com/oss/javascript/integrations/text_embedding/google_generativeai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/text_embedding/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/text_embedding/openai.md',
#  'https://docs.langchain.com/oss/javascript/integrations/tools/index.md',
#  'https://docs.langchain.com/oss/javascript/integrations/vectorstores/index.md',
#  'https://docs.langchain.com/oss/javascript/langchain/academy.md',
#  'https://docs.langchain.com/oss/javascript/langchain/agents.md',
#  'https://docs.langchain.com/oss/javascript/langchain/context-engineering.md',
#  'https://docs.langchain.com/oss/javascript/langchain/deploy.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/INVALID_PROMPT_INPUT.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/INVALID_TOOL_RESULTS.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/MESSAGE_COERCION_FAILURE.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_AUTHENTICATION.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_NOT_FOUND.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/MODEL_RATE_LIMIT.md',
#  'https://docs.langchain.com/oss/javascript/langchain/errors/OUTPUT_PARSING_FAILURE.md',
#  'https://docs.langchain.com/oss/javascript/langchain/guardrails.md',
#  'https://docs.langchain.com/oss/javascript/langchain/human-in-the-loop.md',
#  'https://docs.langchain.com/oss/javascript/langchain/install.md',
#  'https://docs.langchain.com/oss/javascript/langchain/knowledge-base.md',
#  'https://docs.langchain.com/oss/javascript/langchain/long-term-memory.md',
#  'https://docs.langchain.com/oss/javascript/langchain/mcp.md',
#  'https://docs.langchain.com/oss/javascript/langchain/messages.md',
#  'https://docs.langchain.com/oss/javascript/langchain/middleware.md',
#  'https://docs.langchain.com/oss/javascript/langchain/models.md',
#  'https://docs.langchain.com/oss/javascript/langchain/multi-agent.md',
#  'https://docs.langchain.com/oss/javascript/langchain/observability.md',
#  'https://docs.langchain.com/oss/javascript/langchain/overview.md',
#  'https://docs.langchain.com/oss/javascript/langchain/philosophy.md',
#  'https://docs.langchain.com/oss/javascript/langchain/quickstart.md',
#  'https://docs.langchain.com/oss/javascript/langchain/rag.md',
#  'https://docs.langchain.com/oss/javascript/langchain/retrieval.md',
#  'https://docs.langchain.com/oss/javascript/langchain/runtime.md',
#  'https://docs.langchain.com/oss/javascript/langchain/short-term-memory.md',
#  'https://docs.langchain.com/oss/javascript/langchain/sql-agent.md',
#  'https://docs.langchain.com/oss/javascript/langchain/streaming.md',
#  'https://docs.langchain.com/oss/javascript/langchain/structured-output.md',
#  'https://docs.langchain.com/oss/javascript/langchain/studio.md',
#  'https://docs.langchain.com/oss/javascript/langchain/supervisor.md',
#  'https://docs.langchain.com/oss/javascript/langchain/test.md',
#  'https://docs.langchain.com/oss/javascript/langchain/tools.md',
#  'https://docs.langchain.com/oss/javascript/langchain/ui.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/add-memory.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/agentic-rag.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/application-structure.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/case-studies.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/deploy.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/durable-execution.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/GRAPH_RECURSION_LIMIT.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_CHAT_HISTORY.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/INVALID_GRAPH_NODE_RETURN_VALUE.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/MISSING_CHECKPOINTER.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/errors/MULTIPLE_SUBGRAPHS.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/functional-api.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/graph-api.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/install.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/interrupts.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/local-server.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/observability.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/overview.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/persistence.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/pregel.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/quickstart.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/streaming.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/studio.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/test.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/thinking-in-langgraph.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/ui.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/use-functional-api.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/use-graph-api.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/use-subgraphs.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/use-time-travel.md',
#  'https://docs.langchain.com/oss/javascript/langgraph/workflows-agents.md',
#  'https://docs.langchain.com/oss/javascript/learn.md',
#  'https://docs.langchain.com/oss/javascript/migrate/langchain-v1.md',
#  'https://docs.langchain.com/oss/javascript/migrate/langgraph-v1.md',
#  'https://docs.langchain.com/oss/javascript/reference/langchain-javascript.md',
#  'https://docs.langchain.com/oss/javascript/reference/langgraph-javascript.md',
#  'https://docs.langchain.com/oss/javascript/reference/overview.md',
#  'https://docs.langchain.com/oss/javascript/release-policy.md',
#  'https://docs.langchain.com/oss/javascript/releases/langchain-v1.md',
#  'https://docs.langchain.com/oss/javascript/releases/langgraph-v1.md',
#  'https://docs.langchain.com/oss/javascript/security-policy.md',
#  'https://docs.langchain.com/oss/javascript/versioning.md',
#  'https://docs.langchain.com/oss/python/common-errors.md',
#  'https://docs.langchain.com/oss/python/concepts/context.md',
#  'https://docs.langchain.com/oss/python/concepts/memory.md',
#  'https://docs.langchain.com/oss/python/contributing/code.md',
#  'https://docs.langchain.com/oss/python/contributing/comarketing.md',
#  'https://docs.langchain.com/oss/python/contributing/documentation.md',
#  'https://docs.langchain.com/oss/python/contributing/implement-langchain.md',
#  'https://docs.langchain.com/oss/python/contributing/implement-langgraph.md',
#  'https://docs.langchain.com/oss/python/contributing/integrations-langchain.md',
#  'https://docs.langchain.com/oss/python/contributing/integrations-langgraph.md',
#  'https://docs.langchain.com/oss/python/contributing/overview.md',
#  'https://docs.langchain.com/oss/python/contributing/publish-langchain.md',
#  'https://docs.langchain.com/oss/python/contributing/publish-langgraph.md',
#  'https://docs.langchain.com/oss/python/contributing/standard-tests-langchain.md',
#  'https://docs.langchain.com/oss/python/contributing/standard-tests-langgraph.md',
#  'https://docs.langchain.com/oss/python/deepagents/backends.md',
#  'https://docs.langchain.com/oss/python/deepagents/customization.md',
#  'https://docs.langchain.com/oss/python/deepagents/harness.md',
#  'https://docs.langchain.com/oss/python/deepagents/human-in-the-loop.md',
#  'https://docs.langchain.com/oss/python/deepagents/long-term-memory.md',
#  'https://docs.langchain.com/oss/python/deepagents/overview.md',
#  'https://docs.langchain.com/oss/python/deepagents/quickstart.md',
#  'https://docs.langchain.com/oss/python/deepagents/subagents.md',
#  'https://docs.langchain.com/oss/python/integrations/chat/index.md',
#  'https://docs.langchain.com/oss/python/integrations/document_loaders/index.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/all_providers.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/anthropic.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/aws.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/google.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/huggingface.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/microsoft.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/ollama.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/openai.md',
#  'https://docs.langchain.com/oss/python/integrations/providers/overview.md',
#  'https://docs.langchain.com/oss/python/integrations/retrievers/index.md',
#  'https://docs.langchain.com/oss/python/integrations/splitters/index.md',
#  'https://docs.langchain.com/oss/python/integrations/stores/index.md',
#  'https://docs.langchain.com/oss/python/integrations/text_embedding/index.md',
#  'https://docs.langchain.com/oss/python/integrations/tools/index.md',
#  'https://docs.langchain.com/oss/python/integrations/vectorstores/index.md',
#  'https://docs.langchain.com/oss/python/langchain/academy.md',
#  'https://docs.langchain.com/oss/python/langchain/agents.md',
#  'https://docs.langchain.com/oss/python/langchain/context-engineering.md',
#  'https://docs.langchain.com/oss/python/langchain/deploy.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/INVALID_PROMPT_INPUT.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/INVALID_TOOL_RESULTS.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/MESSAGE_COERCION_FAILURE.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/MODEL_AUTHENTICATION.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/MODEL_NOT_FOUND.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/MODEL_RATE_LIMIT.md',
#  'https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE.md',
#  'https://docs.langchain.com/oss/python/langchain/guardrails.md',
#  'https://docs.langchain.com/oss/python/langchain/human-in-the-loop.md',
#  'https://docs.langchain.com/oss/python/langchain/install.md',
#  'https://docs.langchain.com/oss/python/langchain/knowledge-base.md',
#  'https://docs.langchain.com/oss/python/langchain/long-term-memory.md',
#  'https://docs.langchain.com/oss/python/langchain/mcp.md',
#  'https://docs.langchain.com/oss/python/langchain/messages.md',
#  'https://docs.langchain.com/oss/python/langchain/middleware.md',
#  'https://docs.langchain.com/oss/python/langchain/models.md',
#  'https://docs.langchain.com/oss/python/langchain/multi-agent.md',
#  'https://docs.langchain.com/oss/python/langchain/observability.md',
#  'https://docs.langchain.com/oss/python/langchain/overview.md',
#  'https://docs.langchain.com/oss/python/langchain/philosophy.md',
#  'https://docs.langchain.com/oss/python/langchain/quickstart.md',
#  'https://docs.langchain.com/oss/python/langchain/rag.md',
#  'https://docs.langchain.com/oss/python/langchain/retrieval.md',
#  'https://docs.langchain.com/oss/python/langchain/runtime.md',
#  'https://docs.langchain.com/oss/python/langchain/short-term-memory.md',
#  'https://docs.langchain.com/oss/python/langchain/sql-agent.md',
#  'https://docs.langchain.com/oss/python/langchain/streaming.md',
#  'https://docs.langchain.com/oss/python/langchain/structured-output.md',
#  'https://docs.langchain.com/oss/python/langchain/studio.md',
#  'https://docs.langchain.com/oss/python/langchain/supervisor.md',
#  'https://docs.langchain.com/oss/python/langchain/test.md',
#  'https://docs.langchain.com/oss/python/langchain/tools.md',
#  'https://docs.langchain.com/oss/python/langchain/ui.md',
#  'https://docs.langchain.com/oss/python/langgraph/add-memory.md',
#  'https://docs.langchain.com/oss/python/langgraph/agentic-rag.md',
#  'https://docs.langchain.com/oss/python/langgraph/application-structure.md',
#  'https://docs.langchain.com/oss/python/langgraph/case-studies.md',
#  'https://docs.langchain.com/oss/python/langgraph/deploy.md',
#  'https://docs.langchain.com/oss/python/langgraph/durable-execution.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CHAT_HISTORY.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_GRAPH_NODE_RETURN_VALUE.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/MISSING_CHECKPOINTER.md',
#  'https://docs.langchain.com/oss/python/langgraph/errors/MULTIPLE_SUBGRAPHS.md',
#  'https://docs.langchain.com/oss/python/langgraph/functional-api.md',
#  'https://docs.langchain.com/oss/python/langgraph/graph-api.md',
#  'https://docs.langchain.com/oss/python/langgraph/install.md',
#  'https://docs.langchain.com/oss/python/langgraph/interrupts.md',
#  'https://docs.langchain.com/oss/python/langgraph/local-server.md',
#  'https://docs.langchain.com/oss/python/langgraph/observability.md',
#  'https://docs.langchain.com/oss/python/langgraph/overview.md',
#  'https://docs.langchain.com/oss/python/langgraph/persistence.md',
#  'https://docs.langchain.com/oss/python/langgraph/pregel.md',
#  'https://docs.langchain.com/oss/python/langgraph/quickstart.md',
#  'https://docs.langchain.com/oss/python/langgraph/sql-agent.md',
#  'https://docs.langchain.com/oss/python/langgraph/streaming.md',
#  'https://docs.langchain.com/oss/python/langgraph/studio.md',
#  'https://docs.langchain.com/oss/python/langgraph/test.md',
#  'https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph.md',
#  'https://docs.langchain.com/oss/python/langgraph/ui.md',
#  'https://docs.langchain.com/oss/python/langgraph/use-functional-api.md',
#  'https://docs.langchain.com/oss/python/langgraph/use-graph-api.md',
#  'https://docs.langchain.com/oss/python/langgraph/use-subgraphs.md',
#  'https://docs.langchain.com/oss/python/langgraph/use-time-travel.md',
#  'https://docs.langchain.com/oss/python/langgraph/workflows-agents.md',
#  'https://docs.langchain.com/oss/python/learn.md',
#  'https://docs.langchain.com/oss/python/migrate/langchain-v1.md',
#  'https://docs.langchain.com/oss/python/migrate/langgraph-v1.md',
#  'https://docs.langchain.com/oss/python/reference/deepagents-python.md',
#  'https://docs.langchain.com/oss/python/reference/integrations-python.md',
#  'https://docs.langchain.com/oss/python/reference/langchain-python.md',
#  'https://docs.langchain.com/oss/python/reference/langgraph-python.md',
#  'https://docs.langchain.com/oss/python/reference/overview.md',
#  'https://docs.langchain.com/oss/python/release-policy.md',
#  'https://docs.langchain.com/oss/python/releases/langchain-v1.md',
#  'https://docs.langchain.com/oss/python/releases/langgraph-v1.md',
#  'https://docs.langchain.com/oss/python/security-policy.md',
#  'https://docs.langchain.com/oss/python/versioning.md']

# %%
from langchain_core.documents import Document
import uuid

document_structures=[]

for i,(topic,url) in enumerate(zip(topics,urls)):
    doc = Document(
        id=f"doc_{uuid.uuid4().hex[:8]}_{i}",
        page_content=topic,
        metadata={
            "url":url
        }
    )
    document_structures.append(doc)

# %%
document_structures
# Out:
# [Document(id='doc_aec5eb07_0', metadata={'url': 'https://docs.langchain.com/index.md'}, page_content='null'),
#  Document(id='doc_c0865835_1', metadata={'url': 'https://docs.langchain.com/langsmith/add-auth-server.md'}, page_content='Connect an authentication provider'),
#  Document(id='doc_1b4741a8_2', metadata={'url': 'https://docs.langchain.com/langsmith/add-human-in-the-loop.md'}, page_content='Human-in-the-loop using server API'),
#  Document(id='doc_6f7e215f_3', metadata={'url': 'https://docs.langchain.com/langsmith/add-metadata-tags.md'}, page_content='Add metadata and tags to traces'),
#  Document(id='doc_ff7b3ddf_4', metadata={'url': 'https://docs.langchain.com/langsmith/administration-overview.md'}, page_content='Overview'),
#  Document(id='doc_bb4e7970_5', metadata={'url': 'https://docs.langchain.com/langsmith/agent-auth.md'}, page_content='Set up Agent Auth (Beta)'),
#  Document(id='doc_fe1c6b0f_6', metadata={'url': 'https://docs.langchain.com/langsmith/agent-builder.md'}, page_content='Agent Builder'),
#  Document(id='doc_1a56c9be_7', metadata={'url': 'https://docs.langchain.com/langsmith/agent-builder-setup.md'}, page_content='Agent Builder setup'),
#  Document(id='doc_3dd8fc29_8', metadata={'url': 'https://docs.langchain.com/langsmith/agent-builder-tools.md'}, page_content='Supported tools'),
#  Document(id='doc_ce5a8f3a_9', metadata={'url': 'https://docs.langchain.com/langsmith/alerts.md'}, page_content='Alerts in LangSmith'),
#  Document(id='doc_eb354276_10', metadata={'url': 'https://docs.langchain.com/langsmith/alerts-webhook.md'}, page_content='Configure webhook notifications for LangSmith alerts'),
#  Document(id='doc_5b509418_11', metadata={'url': 'https://docs.langchain.com/langsmith/analyze-an-experiment.md'}, page_content='Analyze an experiment'),
#  Document(id='doc_943559d6_12', metadata={'url': 'https://docs.langchain.com/langsmith/annotate-code.md'}, page_content='Custom instrumentation'),
#  Document(id='doc_0355dbba_13', metadata={'url': 'https://docs.langchain.com/langsmith/annotate-traces-inline.md'}, page_content='Annotate traces and runs inline'),
#  Document(id='doc_6953a14f_14', metadata={'url': 'https://docs.langchain.com/langsmith/annotation-queues.md'}, page_content='Use annotation queues'),
#  Document(id='doc_a5b238c1_15', metadata={'url': 'https://docs.langchain.com/langsmith/api-ref-control-plane.md'}, page_content='Control plane API reference for LangSmith Deployment'),
#  Document(id='doc_e4c0cb84_16', metadata={'url': 'https://docs.langchain.com/langsmith/app-development.md'}, page_content='App development in LangSmith Deployment'),
#  Document(id='doc_9b353abc_17', metadata={'url': 'https://docs.langchain.com/langsmith/application-structure.md'}, page_content='Application structure'),
#  Document(id='doc_ca29f797_18', metadata={'url': 'https://docs.langchain.com/langsmith/assistants.md'}, page_content='Assistants'),
#  Document(id='doc_61f155cc_19', metadata={'url': 'https://docs.langchain.com/langsmith/attach-user-feedback.md'}, page_content='Log user feedback using the SDK'),
#  Document(id='doc_abdd2084_20', metadata={'url': 'https://docs.langchain.com/langsmith/audit-evaluator-scores.md'}, page_content='How to audit evaluator scores'),
#  Document(id='doc_37318cb1_21', metadata={'url': 'https://docs.langchain.com/langsmith/auth.md'}, page_content='Authentication & access control'),
#  Document(id='doc_c2783321_22', metadata={'url': 'https://docs.langchain.com/langsmith/authentication-methods.md'}, page_content='Authentication methods'),
#  Document(id='doc_0fc1686f_23', metadata={'url': 'https://docs.langchain.com/langsmith/autogen-integration.md'}, page_content='How to integrate LangGraph with AutoGen, CrewAI, and other frameworks'),
#  Document(id='doc_fd2d18a7_24', metadata={'url': 'https://docs.langchain.com/langsmith/background-run.md'}, page_content='How to kick off background runs'),
#  Document(id='doc_7ae75973_25', metadata={'url': 'https://docs.langchain.com/langsmith/billing.md'}, page_content='Manage billing in your account'),
#  Document(id='doc_0b528e63_26', metadata={'url': 'https://docs.langchain.com/langsmith/bind-evaluator-to-dataset.md'}, page_content='Automatically run evaluators on experiments'),
#  Document(id='doc_0a5dfcc1_27', metadata={'url': 'https://docs.langchain.com/langsmith/cicd-pipeline-example.md'}, page_content='Implement a CI/CD pipeline using LangSmith Deployments and Evaluation'),
#  Document(id='doc_151ce5e1_28', metadata={'url': 'https://docs.langchain.com/langsmith/cli.md'}, page_content='LangGraph CLI'),
#  Document(id='doc_f83a3de8_29', metadata={'url': 'https://docs.langchain.com/langsmith/cloud.md'}, page_content='Cloud'),
#  Document(id='doc_5a620f20_30', metadata={'url': 'https://docs.langchain.com/langsmith/code-evaluator.md'}, page_content='How to define a code evaluator'),
#  Document(id='doc_9240ea30_31', metadata={'url': 'https://docs.langchain.com/langsmith/collector-proxy.md'}, page_content='Beta LangSmith Collector-Proxy'),
#  Document(id='doc_1fe68645_32', metadata={'url': 'https://docs.langchain.com/langsmith/compare-experiment-results.md'}, page_content='How to compare experiment results'),
#  Document(id='doc_84d428de_33', metadata={'url': 'https://docs.langchain.com/langsmith/compare-traces.md'}, page_content='Compare traces'),
#  Document(id='doc_df03c560_34', metadata={'url': 'https://docs.langchain.com/langsmith/components.md'}, page_content='LangSmith components'),
#  Document(id='doc_90f3c687_35', metadata={'url': 'https://docs.langchain.com/langsmith/composite-evaluators.md'}, page_content='Composite evaluators'),
#  Document(id='doc_88f7c834_36', metadata={'url': 'https://docs.langchain.com/langsmith/configurable-headers.md'}, page_content='Configurable headers'),
#  Document(id='doc_c6a62d57_37', metadata={'url': 'https://docs.langchain.com/langsmith/configuration-cloud.md'}, page_content='Manage assistants'),
#  Document(id='doc_97145572_38', metadata={'url': 'https://docs.langchain.com/langsmith/configure-ttl.md'}, page_content='How to add TTLs to your application'),
#  Document(id='doc_52d72eb0_39', metadata={'url': 'https://docs.langchain.com/langsmith/control-plane.md'}, page_content='LangSmith control plane'),
#  Document(id='doc_29c4f845_40', metadata={'url': 'https://docs.langchain.com/langsmith/create-a-prompt.md'}, page_content='Create a prompt'),
#  Document(id='doc_ef287a55_41', metadata={'url': 'https://docs.langchain.com/langsmith/create-account-api-key.md'}, page_content='Create an account and API key'),
#  Document(id='doc_abd9df79_42', metadata={'url': 'https://docs.langchain.com/langsmith/create-few-shot-evaluators.md'}, page_content='How to improve your evaluator with few-shot examples'),
#  Document(id='doc_acb32be5_43', metadata={'url': 'https://docs.langchain.com/langsmith/cron-jobs.md'}, page_content='Use cron jobs'),
#  Document(id='doc_134b75c4_44', metadata={'url': 'https://docs.langchain.com/langsmith/custom-auth.md'}, page_content='Add custom authentication'),
#  Document(id='doc_d9214cac_45', metadata={'url': 'https://docs.langchain.com/langsmith/custom-docker.md'}, page_content='How to customize the Dockerfile'),
#  Document(id='doc_2e3f1d75_46', metadata={'url': 'https://docs.langchain.com/langsmith/custom-endpoint.md'}, page_content='Connect to a custom model'),
#  Document(id='doc_855d934b_47', metadata={'url': 'https://docs.langchain.com/langsmith/custom-lifespan.md'}, page_content='How to add custom lifespan events'),
#  Document(id='doc_1f93c993_48', metadata={'url': 'https://docs.langchain.com/langsmith/custom-middleware.md'}, page_content='How to add custom middleware'),
#  Document(id='doc_94e31b41_49', metadata={'url': 'https://docs.langchain.com/langsmith/custom-openai-compliant-model.md'}, page_content='Connect to an OpenAI compliant model provider/proxy'),
#  Document(id='doc_ddefcc96_50', metadata={'url': 'https://docs.langchain.com/langsmith/custom-output-rendering.md'}, page_content='Custom output rendering'),
#  Document(id='doc_e50f93e9_51', metadata={'url': 'https://docs.langchain.com/langsmith/custom-routes.md'}, page_content='How to add custom routes'),
#  Document(id='doc_b52642cd_52', metadata={'url': 'https://docs.langchain.com/langsmith/dashboards.md'}, page_content='Monitor projects with dashboards'),
#  Document(id='doc_f04ab2b4_53', metadata={'url': 'https://docs.langchain.com/langsmith/data-export.md'}, page_content='Bulk Exporting Trace Data'),
#  Document(id='doc_af8cadc3_54', metadata={'url': 'https://docs.langchain.com/langsmith/data-plane.md'}, page_content='LangSmith data plane'),
#  Document(id='doc_dbc4383c_55', metadata={'url': 'https://docs.langchain.com/langsmith/data-purging-compliance.md'}, page_content='Data purging for compliance'),
#  Document(id='doc_47892c4f_56', metadata={'url': 'https://docs.langchain.com/langsmith/data-storage-and-privacy.md'}, page_content='Data storage and privacy'),
#  Document(id='doc_9bf5566d_57', metadata={'url': 'https://docs.langchain.com/langsmith/dataset-json-types.md'}, page_content='Dataset prebuilt JSON schema types'),
#  Document(id='doc_287b6ff1_58', metadata={'url': 'https://docs.langchain.com/langsmith/dataset-transformations.md'}, page_content='Dataset transformations'),
#  Document(id='doc_90ca30fe_59', metadata={'url': 'https://docs.langchain.com/langsmith/define-target-function.md'}, page_content='How to define a target function to evaluate'),
#  Document(id='doc_83e23d43_60', metadata={'url': 'https://docs.langchain.com/langsmith/deploy-hybrid.md'}, page_content='Set up hybrid LangSmith'),
#  Document(id='doc_164fafd2_61', metadata={'url': 'https://docs.langchain.com/langsmith/deploy-self-hosted-full-platform.md'}, page_content='Enable LangSmith Deployment'),
#  Document(id='doc_ab0ccf23_62', metadata={'url': 'https://docs.langchain.com/langsmith/deploy-standalone-server.md'}, page_content='Self-host standalone servers'),
#  Document(id='doc_c43917e4_63', metadata={'url': 'https://docs.langchain.com/langsmith/deploy-to-cloud.md'}, page_content='LangSmith on Cloud'),
#  Document(id='doc_2c0aef74_64', metadata={'url': 'https://docs.langchain.com/langsmith/deploy-with-control-plane.md'}, page_content='Deploy with control plane'),
#  Document(id='doc_5929a951_65', metadata={'url': 'https://docs.langchain.com/langsmith/deployment-quickstart.md'}, page_content='Deploy your app to Cloud'),
#  Document(id='doc_bf2ecba4_66', metadata={'url': 'https://docs.langchain.com/langsmith/deployments.md'}, page_content='LangSmith Deployment'),
#  Document(id='doc_381c9321_67', metadata={'url': 'https://docs.langchain.com/langsmith/distributed-tracing.md'}, page_content='Implement distributed tracing'),
#  Document(id='doc_dde33c3c_68', metadata={'url': 'https://docs.langchain.com/langsmith/docker.md'}, page_content='Self-host LangSmith with Docker'),
#  Document(id='doc_4f90d863_69', metadata={'url': 'https://docs.langchain.com/langsmith/double-texting.md'}, page_content='Double texting'),
#  Document(id='doc_81eb6c65_70', metadata={'url': 'https://docs.langchain.com/langsmith/enqueue-concurrent.md'}, page_content='Enqueue concurrent'),
#  Document(id='doc_173b9bdd_71', metadata={'url': 'https://docs.langchain.com/langsmith/env-var.md'}, page_content='Environment variables'),
#  Document(id='doc_dc57f6e7_72', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-chatbot-tutorial.md'}, page_content='Evaluate a chatbot'),
#  Document(id='doc_4e6da3e0_73', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-complex-agent.md'}, page_content='Evaluate a complex agent'),
#  Document(id='doc_aef09806_74', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-existing-experiment.md'}, page_content='How to evaluate an existing experiment (Python only)'),
#  Document(id='doc_99fff26f_75', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-graph.md'}, page_content='How to evaluate a graph'),
#  Document(id='doc_023244bb_76', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-llm-application.md'}, page_content='How to evaluate an LLM application'),
#  Document(id='doc_01719743_77', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-on-intermediate-steps.md'}, page_content="How to evaluate an application's intermediate steps"),
#  Document(id='doc_a3559305_78', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-pairwise.md'}, page_content='How to run a pairwise evaluation'),
#  Document(id='doc_3a495179_79', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-rag-tutorial.md'}, page_content='Evaluate a RAG application'),
#  Document(id='doc_96af5c18_80', metadata={'url': 'https://docs.langchain.com/langsmith/evaluate-with-attachments.md'}, page_content='Run an evaluation with multimodal content'),
#  Document(id='doc_a877e686_81', metadata={'url': 'https://docs.langchain.com/langsmith/evaluation.md'}, page_content='LangSmith Evaluations'),
#  Document(id='doc_becacf5d_82', metadata={'url': 'https://docs.langchain.com/langsmith/evaluation-approaches.md'}, page_content='Application-specific evaluation approaches'),
#  Document(id='doc_3344aaed_83', metadata={'url': 'https://docs.langchain.com/langsmith/evaluation-async.md'}, page_content='How to run an evaluation asynchronously'),
#  Document(id='doc_440faddf_84', metadata={'url': 'https://docs.langchain.com/langsmith/evaluation-concepts.md'}, page_content='Evaluation Concepts'),
#  Document(id='doc_3ec1ac33_85', metadata={'url': 'https://docs.langchain.com/langsmith/evaluation-quickstart.md'}, page_content='Evaluation quickstart'),
#  Document(id='doc_8e5182f0_86', metadata={'url': 'https://docs.langchain.com/langsmith/example-data-format.md'}, page_content='Example data format'),
#  Document(id='doc_1eecf0ae_87', metadata={'url': 'https://docs.langchain.com/langsmith/export-backend.md'}, page_content='Export LangSmith telemetry to your observability backend'),
#  Document(id='doc_ebb811aa_88', metadata={'url': 'https://docs.langchain.com/langsmith/export-traces.md'}, page_content='Query traces (SDK)'),
#  Document(id='doc_62292554_89', metadata={'url': 'https://docs.langchain.com/langsmith/faq.md'}, page_content='Frequently asked questions'),
#  Document(id='doc_ed22e79f_90', metadata={'url': 'https://docs.langchain.com/langsmith/feedback-data-format.md'}, page_content='Feedback data format'),
#  Document(id='doc_3f75f46b_91', metadata={'url': 'https://docs.langchain.com/langsmith/fetch-perf-metrics-experiment.md'}, page_content='How to fetch performance metrics for an experiment'),
#  Document(id='doc_4aec9ee4_92', metadata={'url': 'https://docs.langchain.com/langsmith/filter-experiments-ui.md'}, page_content='How to filter experiments in the UI'),
#  Document(id='doc_536f65e1_93', metadata={'url': 'https://docs.langchain.com/langsmith/filter-traces-in-application.md'}, page_content='Filter traces'),
#  Document(id='doc_48ae4892_94', metadata={'url': 'https://docs.langchain.com/langsmith/generative-ui-react.md'}, page_content='How to implement generative user interfaces with LangGraph'),
#  Document(id='doc_422833e4_95', metadata={'url': 'https://docs.langchain.com/langsmith/graph-rebuild.md'}, page_content='Rebuild graph at runtime'),
#  Document(id='doc_1bf584b0_96', metadata={'url': 'https://docs.langchain.com/langsmith/home.md'}, page_content='LangSmith docs'),
#  Document(id='doc_c64d6698_97', metadata={'url': 'https://docs.langchain.com/langsmith/human-in-the-loop-time-travel.md'}, page_content='Time travel using the server API'),
#  Document(id='doc_0386da1e_98', metadata={'url': 'https://docs.langchain.com/langsmith/hybrid.md'}, page_content='Hybrid'),
#  Document(id='doc_b39059b7_99', metadata={'url': 'https://docs.langchain.com/langsmith/improve-judge-evaluator-feedback.md'}, page_content='Improve LLM-as-judge evaluators using human feedback'),
#  Document(id='doc_4221e03b_100', metadata={'url': 'https://docs.langchain.com/langsmith/index-datasets-for-dynamic-few-shot-example-selection.md'}, page_content='Dynamic few shot example selection'),
#  Document(id='doc_f1d9bd99_101', metadata={'url': 'https://docs.langchain.com/langsmith/insights.md'}, page_content='Discover errors and usage patterns with the Insights Agent'),
#  Document(id='doc_24f894d8_102', metadata={'url': 'https://docs.langchain.com/langsmith/integrations.md'}, page_content='Integrations'),
#  Document(id='doc_846f8c4a_103', metadata={'url': 'https://docs.langchain.com/langsmith/interrupt-concurrent.md'}, page_content='Interrupt concurrent'),
#  Document(id='doc_f41a68df_104', metadata={'url': 'https://docs.langchain.com/langsmith/kubernetes.md'}, page_content='Self-host LangSmith on Kubernetes'),
#  Document(id='doc_38191914_105', metadata={'url': 'https://docs.langchain.com/langsmith/langchain-runnable.md'}, page_content='How to evaluate a runnable'),
#  Document(id='doc_b544d268_106', metadata={'url': 'https://docs.langchain.com/langsmith/langgraph-js-ts-sdk.md'}, page_content='LangGraph JS/TS SDK'),
#  Document(id='doc_5b02a662_107', metadata={'url': 'https://docs.langchain.com/langsmith/langgraph-python-sdk.md'}, page_content='LangGraph Python SDK'),
#  Document(id='doc_8e10ce39_108', metadata={'url': 'https://docs.langchain.com/langsmith/langgraph-server.md'}, page_content='LangGraph Server'),
#  Document(id='doc_2977cbae_109', metadata={'url': 'https://docs.langchain.com/langsmith/langgraph-server-changelog.md'}, page_content='LangGraph Server changelog'),
#  Document(id='doc_dc407edf_110', metadata={'url': 'https://docs.langchain.com/langsmith/langsmith-collector.md'}, page_content='Configure your collector for LangSmith telemetry'),
#  Document(id='doc_a7dfe0ce_111', metadata={'url': 'https://docs.langchain.com/langsmith/langsmith-managed-clickhouse.md'}, page_content='LangSmith-managed ClickHouse'),
#  Document(id='doc_8518c0ab_112', metadata={'url': 'https://docs.langchain.com/langsmith/llm-as-judge.md'}, page_content='How to define an LLM-as-a-judge evaluator'),
#  Document(id='doc_9b9d230f_113', metadata={'url': 'https://docs.langchain.com/langsmith/local.md'}, page_content='How to run an evaluation locally (Python only)'),
#  Document(id='doc_07eda14d_114', metadata={'url': 'https://docs.langchain.com/langsmith/local-server.md'}, page_content='Run a LangGraph app locally'),
#  Document(id='doc_11e57348_115', metadata={'url': 'https://docs.langchain.com/langsmith/log-llm-trace.md'}, page_content='Log LLM calls'),
#  Document(id='doc_b4a604b1_116', metadata={'url': 'https://docs.langchain.com/langsmith/log-multimodal-traces.md'}, page_content='Log multimodal traces'),
#  Document(id='doc_261cc920_117', metadata={'url': 'https://docs.langchain.com/langsmith/log-retriever-trace.md'}, page_content='Log retriever traces'),
#  Document(id='doc_9ba4ea53_118', metadata={'url': 'https://docs.langchain.com/langsmith/log-traces-to-project.md'}, page_content='Log traces to a specific project'),
#  Document(id='doc_38722021_119', metadata={'url': 'https://docs.langchain.com/langsmith/manage-datasets.md'}, page_content='Manage datasets'),
#  Document(id='doc_723c10dc_120', metadata={'url': 'https://docs.langchain.com/langsmith/manage-datasets-in-application.md'}, page_content='Create and manage datasets in the UI'),
#  Document(id='doc_d43c7930_121', metadata={'url': 'https://docs.langchain.com/langsmith/manage-datasets-programmatically.md'}, page_content='How to create and manage datasets programmatically'),
#  Document(id='doc_948fb9b0_122', metadata={'url': 'https://docs.langchain.com/langsmith/manage-organization-by-api.md'}, page_content='Manage your organization using the API'),
#  Document(id='doc_02b9ff67_123', metadata={'url': 'https://docs.langchain.com/langsmith/manage-prompts.md'}, page_content='Manage prompts'),
#  Document(id='doc_d95b7687_124', metadata={'url': 'https://docs.langchain.com/langsmith/manage-prompts-programmatically.md'}, page_content='Manage prompts programmatically'),
#  Document(id='doc_2a3fe5af_125', metadata={'url': 'https://docs.langchain.com/langsmith/managing-model-configurations.md'}, page_content='Configure prompt settings'),
#  Document(id='doc_114ee565_126', metadata={'url': 'https://docs.langchain.com/langsmith/mask-inputs-outputs.md'}, page_content='Prevent logging of sensitive data in traces'),
#  Document(id='doc_54130b1f_127', metadata={'url': 'https://docs.langchain.com/langsmith/metric-type.md'}, page_content='How to return categorical vs numerical metrics'),
#  Document(id='doc_e77a42fa_128', metadata={'url': 'https://docs.langchain.com/langsmith/monorepo-support.md'}, page_content='Monorepo support'),
#  Document(id='doc_d1822335_129', metadata={'url': 'https://docs.langchain.com/langsmith/multi-turn-simulation.md'}, page_content='How to simulate multi-turn interactions'),
#  Document(id='doc_3345f9b9_130', metadata={'url': 'https://docs.langchain.com/langsmith/multimodal-content.md'}, page_content='Include multimodal content in a prompt'),
#  Document(id='doc_5c117cfd_131', metadata={'url': 'https://docs.langchain.com/langsmith/multiple-messages.md'}, page_content='Test multi-turn conversations'),
#  Document(id='doc_42df4294_132', metadata={'url': 'https://docs.langchain.com/langsmith/multiple-scores.md'}, page_content='How to return multiple scores in one evaluator'),
#  Document(id='doc_214949a8_133', metadata={'url': 'https://docs.langchain.com/langsmith/nest-traces.md'}, page_content='Troubleshoot trace nesting'),
#  Document(id='doc_0f8a9a6f_134', metadata={'url': 'https://docs.langchain.com/langsmith/observability.md'}, page_content='LangSmith Observability'),
#  Document(id='doc_ad3c4b44_135', metadata={'url': 'https://docs.langchain.com/langsmith/observability-concepts.md'}, page_content='Observability concepts'),
#  Document(id='doc_aeed90dc_136', metadata={'url': 'https://docs.langchain.com/langsmith/observability-llm-tutorial.md'}, page_content='Trace a RAG application tutorial'),
#  Document(id='doc_e097b25f_137', metadata={'url': 'https://docs.langchain.com/langsmith/observability-quickstart.md'}, page_content='Tracing quickstart'),
#  Document(id='doc_92a8cdb9_138', metadata={'url': 'https://docs.langchain.com/langsmith/observability-stack.md'}, page_content='Deploy an observability stack for your LangSmith deployment'),
#  Document(id='doc_b5452a76_139', metadata={'url': 'https://docs.langchain.com/langsmith/observability-studio.md'}, page_content='Observability in Studio'),
#  Document(id='doc_3253a153_140', metadata={'url': 'https://docs.langchain.com/langsmith/online-evaluations.md'}, page_content='Set up online evaluators'),
#  Document(id='doc_a9746f0c_141', metadata={'url': 'https://docs.langchain.com/langsmith/openapi-security.md'}, page_content='Document API authentication in OpenAPI'),
#  Document(id='doc_67d2d74c_142', metadata={'url': 'https://docs.langchain.com/langsmith/optimize-classifier.md'}, page_content='Optimize a classifier'),
#  Document(id='doc_b6f9793b_143', metadata={'url': 'https://docs.langchain.com/langsmith/platform-logs.md'}, page_content='View server logs for a trace'),
#  Document(id='doc_2d04e531_144', metadata={'url': 'https://docs.langchain.com/langsmith/platform-setup.md'}, page_content='Set up LangSmith'),
#  Document(id='doc_d8d53ea4_145', metadata={'url': 'https://docs.langchain.com/langsmith/prebuilt-evaluators.md'}, page_content='How to use prebuilt evaluators'),
#  Document(id='doc_d6d41ca1_146', metadata={'url': 'https://docs.langchain.com/langsmith/pricing-faq.md'}, page_content='Frequently Asked Questions'),
#  Document(id='doc_0e8c9f32_147', metadata={'url': 'https://docs.langchain.com/langsmith/pricing-plans.md'}, page_content='Pricing plans'),
#  Document(id='doc_75d4781e_148', metadata={'url': 'https://docs.langchain.com/langsmith/prompt-commit.md'}, page_content='How to sync prompts with GitHub'),
#  Document(id='doc_41e3ec55_149', metadata={'url': 'https://docs.langchain.com/langsmith/prompt-engineering.md'}, page_content='Prompt engineering'),
#  Document(id='doc_89bab0e4_150', metadata={'url': 'https://docs.langchain.com/langsmith/prompt-engineering-concepts.md'}, page_content='Prompt engineering concepts'),
#  Document(id='doc_dc348aca_151', metadata={'url': 'https://docs.langchain.com/langsmith/prompt-engineering-quickstart.md'}, page_content='Prompt engineering quickstart'),
#  Document(id='doc_0d53fb00_152', metadata={'url': 'https://docs.langchain.com/langsmith/pytest.md'}, page_content='How to run evaluations with pytest (beta)'),
#  Document(id='doc_5b7d0145_153', metadata={'url': 'https://docs.langchain.com/langsmith/quick-start-studio.md'}, page_content='Get started with Studio'),
#  Document(id='doc_9ecd51af_154', metadata={'url': 'https://docs.langchain.com/langsmith/rate-limiting.md'}, page_content='How to handle model rate limits'),
#  Document(id='doc_a60d3623_155', metadata={'url': 'https://docs.langchain.com/langsmith/regions-faq.md'}, page_content='Regions FAQ'),
#  Document(id='doc_95a80878_156', metadata={'url': 'https://docs.langchain.com/langsmith/reject-concurrent.md'}, page_content='Reject Concurrent'),
#  Document(id='doc_2cd028b7_157', metadata={'url': 'https://docs.langchain.com/langsmith/release-versions.md'}, page_content='Release versions'),
#  Document(id='doc_a43d8cc7_158', metadata={'url': 'https://docs.langchain.com/langsmith/remote-graph.md'}, page_content='RemoteGraph'),
#  Document(id='doc_6f0fd664_159', metadata={'url': 'https://docs.langchain.com/langsmith/repetition.md'}, page_content='How to evaluate with repetitions'),
#  Document(id='doc_50135784_160', metadata={'url': 'https://docs.langchain.com/langsmith/resource-auth.md'}, page_content='Make conversations private'),
#  Document(id='doc_36b0cb2e_161', metadata={'url': 'https://docs.langchain.com/langsmith/rollback-concurrent.md'}, page_content='Rollback Concurrent'),
#  Document(id='doc_e769e734_162', metadata={'url': 'https://docs.langchain.com/langsmith/rules.md'}, page_content='Set up automation rules'),
#  Document(id='doc_e79d9afe_163', metadata={'url': 'https://docs.langchain.com/langsmith/run-backtests-new-agent.md'}, page_content='Run backtests on a new version of an agent'),
#  Document(id='doc_2da4017e_164', metadata={'url': 'https://docs.langchain.com/langsmith/run-data-format.md'}, page_content='Run (span) data format'),
#  Document(id='doc_fecae86a_165', metadata={'url': 'https://docs.langchain.com/langsmith/run-evals-api-only.md'}, page_content='How to use the REST API'),
#  Document(id='doc_142e2ab8_166', metadata={'url': 'https://docs.langchain.com/langsmith/run-evaluation-from-prompt-playground.md'}, page_content='Run an evaluation from the prompt playground'),
#  Document(id='doc_37ec42e3_167', metadata={'url': 'https://docs.langchain.com/langsmith/same-thread.md'}, page_content='How to run multiple agents on the same thread'),
#  Document(id='doc_6a1ce634_168', metadata={'url': 'https://docs.langchain.com/langsmith/sample-traces.md'}, page_content='Set a sampling rate for traces'),
#  Document(id='doc_5f418079_169', metadata={'url': 'https://docs.langchain.com/langsmith/scalability-and-resilience.md'}, page_content='Scalability & resilience'),
#  Document(id='doc_e581028a_170', metadata={'url': 'https://docs.langchain.com/langsmith/script-delete-a-workspace.md'}, page_content='Delete workspaces'),
#  Document(id='doc_9fc3da63_171', metadata={'url': 'https://docs.langchain.com/langsmith/script-delete-an-organization.md'}, page_content='Delete organizations'),
#  Document(id='doc_7576a4a1_172', metadata={'url': 'https://docs.langchain.com/langsmith/script-delete-traces.md'}, page_content='Delete traces'),
#  Document(id='doc_1b5948f7_173', metadata={'url': 'https://docs.langchain.com/langsmith/script-generate-clickhouse-stats.md'}, page_content='Generate ClickHouse stats'),
#  Document(id='doc_9ec9c669_174', metadata={'url': 'https://docs.langchain.com/langsmith/script-generate-query-stats.md'}, page_content='Generate query stats'),
#  Document(id='doc_55dd55b3_175', metadata={'url': 'https://docs.langchain.com/langsmith/script-running-ch-support-queries.md'}, page_content='Run support queries against ClickHouse'),
#  Document(id='doc_49fc35ba_176', metadata={'url': 'https://docs.langchain.com/langsmith/script-running-pg-support-queries.md'}, page_content='Run support queries against PostgreSQL'),
#  Document(id='doc_8e15b81e_177', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-basic-auth.md'}, page_content='Basic authentication with email and password'),
#  Document(id='doc_cbd4a62e_178', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-blob-storage.md'}, page_content='Enable blob storage'),
#  Document(id='doc_b17d9ff0_179', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-custom-tls-certificates.md'}, page_content='Configure custom TLS certificates'),
#  Document(id='doc_f37ae03d_180', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-egress.md'}, page_content='Egress for subscription metrics and operational metadata'),
#  Document(id='doc_bc841cac_181', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-external-clickhouse.md'}, page_content='Connect to an external ClickHouse database'),
#  Document(id='doc_54beb1ed_182', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-external-postgres.md'}, page_content='Connect to an external PostgreSQL database'),
#  Document(id='doc_68c37432_183', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-external-redis.md'}, page_content='Connect to an external Redis database'),
#  Document(id='doc_b69309fe_184', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-ingress.md'}, page_content='Create an Ingress for installations (Kubernetes)'),
#  Document(id='doc_14d53d49_185', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-mirroring-images.md'}, page_content='Mirror images for your LangSmith installation'),
#  Document(id='doc_8f0d0735_186', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-organization-charts.md'}, page_content='View trace counts across your organization'),
#  Document(id='doc_49ea85f7_187', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-playground-environment-settings.md'}, page_content='Use environment variables for model providers'),
#  Document(id='doc_127e9af3_188', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-scale.md'}, page_content='Configure LangSmith for scale'),
#  Document(id='doc_009fa0cf_189', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-sso.md'}, page_content='Set up SSO with OAuth2.0 and OIDC'),
#  Document(id='doc_ce171d0f_190', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-ttl.md'}, page_content='Enable TTL and data retention'),
#  Document(id='doc_9caabed1_191', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-upgrades.md'}, page_content='Upgrade an installation'),
#  Document(id='doc_542b0dcd_192', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-usage.md'}, page_content='Interact with your self-hosted instance of LangSmith'),
#  Document(id='doc_870d7a0f_193', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-user-management.md'}, page_content='Customize user management'),
#  Document(id='doc_7ec1408d_194', metadata={'url': 'https://docs.langchain.com/langsmith/self-host-using-an-existing-secret.md'}, page_content='Use an existing secret for your installation (Kubernetes)'),
#  Document(id='doc_0d72ee89_195', metadata={'url': 'https://docs.langchain.com/langsmith/self-hosted.md'}, page_content='Self-hosted LangSmith'),
#  Document(id='doc_fa972044_196', metadata={'url': 'https://docs.langchain.com/langsmith/semantic-search.md'}, page_content='How to add semantic search to your agent deployment'),
#  Document(id='doc_79d3677a_197', metadata={'url': 'https://docs.langchain.com/langsmith/server-a2a.md'}, page_content='A2A endpoint in LangGraph Server'),
#  Document(id='doc_07d9dcad_198', metadata={'url': 'https://docs.langchain.com/langsmith/server-api-ref.md'}, page_content='LangGraph Server API reference for LangSmith Deployment'),
#  Document(id='doc_153127e1_199', metadata={'url': 'https://docs.langchain.com/langsmith/server-mcp.md'}, page_content='MCP endpoint in LangGraph Server'),
#  Document(id='doc_20db8166_200', metadata={'url': 'https://docs.langchain.com/langsmith/serverless-environments.md'}, page_content='Trace JS functions in serverless environments'),
#  Document(id='doc_2be0a547_201', metadata={'url': 'https://docs.langchain.com/langsmith/set-up-a-workspace.md'}, page_content='Set up a workspace'),
#  Document(id='doc_e892b791_202', metadata={'url': 'https://docs.langchain.com/langsmith/set-up-custom-auth.md'}, page_content='Set up custom authentication'),
#  Document(id='doc_4d83c2b2_203', metadata={'url': 'https://docs.langchain.com/langsmith/set-up-feedback-criteria.md'}, page_content='Set up feedback criteria'),
#  Document(id='doc_19227cc9_204', metadata={'url': 'https://docs.langchain.com/langsmith/set-up-resource-tags.md'}, page_content='Set up resource tags'),
#  Document(id='doc_108995df_205', metadata={'url': 'https://docs.langchain.com/langsmith/setup-app-requirements-txt.md'}, page_content='How to set up an application with requirements.txt'),
#  Document(id='doc_d6941d50_206', metadata={'url': 'https://docs.langchain.com/langsmith/setup-javascript.md'}, page_content='How to set up a JavaScript application'),
#  Document(id='doc_dd33a9c7_207', metadata={'url': 'https://docs.langchain.com/langsmith/setup-pyproject.md'}, page_content='How to set up an application with pyproject.toml'),
#  Document(id='doc_ffe52985_208', metadata={'url': 'https://docs.langchain.com/langsmith/share-trace.md'}, page_content='Share or unshare a trace publicly'),
#  Document(id='doc_30dcafb8_209', metadata={'url': 'https://docs.langchain.com/langsmith/smith-api-ref.md'}, page_content='LangSmith API reference'),
#  Document(id='doc_2e5b763f_210', metadata={'url': 'https://docs.langchain.com/langsmith/smith-js-ts-sdk.md'}, page_content='LangSmith JS/TS SDK'),
#  Document(id='doc_4384087c_211', metadata={'url': 'https://docs.langchain.com/langsmith/smith-python-sdk.md'}, page_content='LangSmith Python SDK'),
#  Document(id='doc_b54e4002_212', metadata={'url': 'https://docs.langchain.com/langsmith/stateless-runs.md'}, page_content='Stateless runs'),
#  Document(id='doc_2561dec9_213', metadata={'url': 'https://docs.langchain.com/langsmith/streaming.md'}, page_content='Streaming API'),
#  Document(id='doc_3c1c6fc7_214', metadata={'url': 'https://docs.langchain.com/langsmith/studio.md'}, page_content='LangSmith Studio'),
#  Document(id='doc_cdc818f3_215', metadata={'url': 'https://docs.langchain.com/langsmith/summary.md'}, page_content='How to define a summary evaluator'),
#  Document(id='doc_0968c3b5_216', metadata={'url': 'https://docs.langchain.com/langsmith/test-react-agent-pytest.md'}, page_content='Test a ReAct agent with Pytest/Vitest and LangSmith'),
#  Document(id='doc_06b8838c_217', metadata={'url': 'https://docs.langchain.com/langsmith/threads.md'}, page_content='Configure threads'),
#  Document(id='doc_add0bdb8_218', metadata={'url': 'https://docs.langchain.com/langsmith/trace-anthropic.md'}, page_content='Trace with Anthropic'),
#  Document(id='doc_203001eb_219', metadata={'url': 'https://docs.langchain.com/langsmith/trace-claude-agent-sdk.md'}, page_content='Trace Claude Agent SDK'),
#  Document(id='doc_da81e962_220', metadata={'url': 'https://docs.langchain.com/langsmith/trace-claude-code.md'}, page_content='Trace Claude Code'),
#  Document(id='doc_7e93b398_221', metadata={'url': 'https://docs.langchain.com/langsmith/trace-generator-functions.md'}, page_content='Trace generator functions'),
#  Document(id='doc_991605d1_222', metadata={'url': 'https://docs.langchain.com/langsmith/trace-openai.md'}, page_content='Trace with OpenAI'),
#  Document(id='doc_4f329ab4_223', metadata={'url': 'https://docs.langchain.com/langsmith/trace-query-syntax.md'}, page_content='Trace query syntax'),
#  Document(id='doc_03fe8143_224', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-api.md'}, page_content='Trace with API'),
#  Document(id='doc_4e062289_225', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-autogen.md'}, page_content='Trace with AutoGen'),
#  Document(id='doc_705a6f6f_226', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-crewai.md'}, page_content='Trace with CrewAI'),
#  Document(id='doc_ce4e1376_227', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-google-adk.md'}, page_content='Trace with Google ADK'),
#  Document(id='doc_fe0b2b13_228', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-instructor.md'}, page_content='Trace with Instructor'),
#  Document(id='doc_a3f12d45_229', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-langchain.md'}, page_content='Trace with LangChain (Python and JS/TS)'),
#  Document(id='doc_57d6db6c_230', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-langgraph.md'}, page_content='Trace with LangGraph'),
#  Document(id='doc_915f5131_231', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-openai-agents-sdk.md'}, page_content='Trace with OpenAI Agents SDK'),
#  Document(id='doc_ee93ef17_232', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-opentelemetry.md'}, page_content='Trace with OpenTelemetry'),
#  Document(id='doc_a347fb65_233', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-semantic-kernel.md'}, page_content='Trace with Semantic Kernel'),
#  Document(id='doc_2bcff004_234', metadata={'url': 'https://docs.langchain.com/langsmith/trace-with-vercel-ai-sdk.md'}, page_content='Trace with the Vercel AI SDK (JS/TS only)'),
#  Document(id='doc_fb8584bf_235', metadata={'url': 'https://docs.langchain.com/langsmith/trace-without-env-vars.md'}, page_content='Trace without setting environment variables'),
#  Document(id='doc_d0632145_236', metadata={'url': 'https://docs.langchain.com/langsmith/trajectory-evals.md'}, page_content='How to evaluate your agent with trajectory evaluations'),
#  Document(id='doc_9b97a292_237', metadata={'url': 'https://docs.langchain.com/langsmith/troubleshooting.md'}, page_content='Troubleshooting'),
#  Document(id='doc_60bcff06_238', metadata={'url': 'https://docs.langchain.com/langsmith/troubleshooting-studio.md'}, page_content='Studio troubleshooting'),
#  Document(id='doc_b0f6e6f9_239', metadata={'url': 'https://docs.langchain.com/langsmith/troubleshooting-variable-caching.md'}, page_content='Troubleshoot variable caching'),
#  Document(id='doc_c8ee7736_240', metadata={'url': 'https://docs.langchain.com/langsmith/upload-existing-experiments.md'}, page_content='How to upload experiments run outside of LangSmith with the REST API'),
#  Document(id='doc_9db92719_241', metadata={'url': 'https://docs.langchain.com/langsmith/upload-files-with-traces.md'}, page_content='Upload files with traces'),
#  Document(id='doc_d8f6ec10_242', metadata={'url': 'https://docs.langchain.com/langsmith/use-remote-graph.md'}, page_content='How to interact with a deployment using RemoteGraph'),
#  Document(id='doc_35426c35_243', metadata={'url': 'https://docs.langchain.com/langsmith/use-stream-react.md'}, page_content='How to integrate LangGraph into your React application'),
#  Document(id='doc_90bb9de2_244', metadata={'url': 'https://docs.langchain.com/langsmith/use-studio.md'}, page_content='How to use Studio'),
#  Document(id='doc_66455dc0_245', metadata={'url': 'https://docs.langchain.com/langsmith/use-threads.md'}, page_content='Use threads'),
#  Document(id='doc_6f37a224_246', metadata={'url': 'https://docs.langchain.com/langsmith/use-tools.md'}, page_content='Use tools in a prompt'),
#  Document(id='doc_4d4212bf_247', metadata={'url': 'https://docs.langchain.com/langsmith/use-webhooks.md'}, page_content='Use webhooks'),
#  Document(id='doc_1bb2c341_248', metadata={'url': 'https://docs.langchain.com/langsmith/user-management.md'}, page_content='User management'),
#  Document(id='doc_aab8c0cf_249', metadata={'url': 'https://docs.langchain.com/langsmith/vitest-jest.md'}, page_content='How to run evaluations with Vitest/Jest (beta)'),
#  Document(id='doc_94b84c29_250', metadata={'url': 'https://docs.langchain.com/langsmith/webhooks.md'}, page_content='Configure webhook notifications for rules'),
#  Document(id='doc_5b9e21ca_251', metadata={'url': 'https://docs.langchain.com/langsmith/write-prompt-with-ai.md'}, page_content='Write your prompt with AI'),
#  Document(id='doc_6018b06e_252', metadata={'url': 'https://docs.langchain.com/oss/javascript/common-errors.md'}, page_content='Error troubleshooting'),
#  Document(id='doc_41a9bd0a_253', metadata={'url': 'https://docs.langchain.com/oss/javascript/concepts/context.md'}, page_content='Context overview'),
#  Document(id='doc_77a6f81e_254', metadata={'url': 'https://docs.langchain.com/oss/javascript/concepts/memory.md'}, page_content='Memory overview'),
#  Document(id='doc_95384d01_255', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/code.md'}, page_content='Contributing to code'),
#  Document(id='doc_af8ace78_256', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/comarketing.md'}, page_content='Co-marketing'),
#  Document(id='doc_f5642b13_257', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/documentation.md'}, page_content='Contributing to documentation'),
#  Document(id='doc_fa50471d_258', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/implement-langchain.md'}, page_content='Implement a LangChain integration'),
#  Document(id='doc_94cf8c95_259', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/implement-langgraph.md'}, page_content='Implement a LangGraph integration'),
#  Document(id='doc_d47fa834_260', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/integrations-langchain.md'}, page_content='Contributing integrations'),
#  Document(id='doc_1971ceb9_261', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/integrations-langgraph.md'}, page_content='Contributing integrations'),
#  Document(id='doc_07607e0f_262', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/overview.md'}, page_content='Contributing'),
#  Document(id='doc_800e1f89_263', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/publish-langchain.md'}, page_content='Publish an integration'),
#  Document(id='doc_42073e8a_264', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/publish-langgraph.md'}, page_content='Publish an integration'),
#  Document(id='doc_4e52b38a_265', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/standard-tests-langchain.md'}, page_content='Using standard tests'),
#  Document(id='doc_a23f348e_266', metadata={'url': 'https://docs.langchain.com/oss/javascript/contributing/standard-tests-langgraph.md'}, page_content='Using standard tests'),
#  Document(id='doc_77c9aa74_267', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/callbacks/index.md'}, page_content='Callbacks'),
#  Document(id='doc_7c4dce78_268', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/anthropic.md'}, page_content='ChatAnthropic'),
#  Document(id='doc_3ac1171f_269', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/azure.md'}, page_content='AzureChatOpenAI'),
#  Document(id='doc_7aba99a4_270', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/bedrock.md'}, page_content='BedrockChat'),
#  Document(id='doc_086eaa19_271', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/google_generative_ai.md'}, page_content='ChatGoogleGenerativeAI'),
#  Document(id='doc_bfa19a35_272', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/index.md'}, page_content='Chat models'),
#  Document(id='doc_889ddb6d_273', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/chat/openai.md'}, page_content='ChatOpenAI'),
#  Document(id='doc_4d8bf23f_274', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/document_loaders/index.md'}, page_content='null'),
#  Document(id='doc_ba42ebe4_275', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/document_transformers/index.md'}, page_content='Document transformers'),
#  Document(id='doc_84a78330_276', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/llm_caching/index.md'}, page_content='Model caches'),
#  Document(id='doc_96ca8bd9_277', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/llms/index.md'}, page_content='LLMs'),
#  Document(id='doc_ec165cc2_278', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/all_providers.md'}, page_content='All integrations'),
#  Document(id='doc_eea000eb_279', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/anthropic.md'}, page_content='Overview'),
#  Document(id='doc_cea03521_280', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/aws.md'}, page_content='Overview'),
#  Document(id='doc_22b4e143_281', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/google.md'}, page_content='Overview'),
#  Document(id='doc_05302b3a_282', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/microsoft.md'}, page_content='Overview'),
#  Document(id='doc_816bad16_283', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/openai.md'}, page_content='Overview'),
#  Document(id='doc_dbee9ebf_284', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/providers/overview.md'}, page_content='Integration Packages'),
#  Document(id='doc_223792c5_285', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/retrievers/index.md'}, page_content='Retrievers'),
#  Document(id='doc_944cb301_286', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/splitters/index.md'}, page_content='Text splitters'),
#  Document(id='doc_98952103_287', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/stores/index.md'}, page_content='Key-value stores'),
#  Document(id='doc_ca1d45e4_288', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/text_embedding/azure_openai.md'}, page_content='AzureOpenAIEmbeddings'),
#  Document(id='doc_377f4dc7_289', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/text_embedding/bedrock.md'}, page_content='BedrockEmbeddings'),
#  Document(id='doc_aa109cb4_290', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/text_embedding/google_generativeai.md'}, page_content='GoogleGenerativeAIEmbeddings'),
#  Document(id='doc_be520746_291', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/text_embedding/index.md'}, page_content='Embedding models'),
#  Document(id='doc_4148e2ab_292', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/text_embedding/openai.md'}, page_content='OpenAIEmbeddings'),
#  Document(id='doc_f138ba57_293', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/tools/index.md'}, page_content='Tools and Toolkits'),
#  Document(id='doc_8ac2faa0_294', metadata={'url': 'https://docs.langchain.com/oss/javascript/integrations/vectorstores/index.md'}, page_content='Vector stores'),
#  Document(id='doc_908045b2_295', metadata={'url': 'https://docs.langchain.com/oss/javascript/langchain/academy.md'}, page_content='LangChain Academy'),
#  Document(id='doc_7a243d6d_296', metadata={'url': 'https://docs.langchain.com/oss/javascript/langchain/agents.md'}, page_content='Agents'),
#  Document(id='doc_6be1d173_297', metadata={'url': 'https://docs.langchain.com/oss/javascript/langchain/context-engineering.md'}, page_content='Context engineering in agents'),
#  Document(id='doc_eebc42c0_298', metadata={'url': 'https://docs.langchain.com/oss/javascript/langchain/deploy.md'}, page_content='Deploy'),
# ...
#  Document(id='doc_50f348a3_394', metadata={'url': 'https://docs.langchain.com/oss/python/deepagents/long-term-memory.md'}, page_content='Long-term memory'),
#  Document(id='doc_3cb12cfa_395', metadata={'url': 'https://docs.langchain.com/oss/python/deepagents/overview.md'}, page_content='Deep Agents overview'),
#  Document(id='doc_d4d19ca8_396', metadata={'url': 'https://docs.langchain.com/oss/python/deepagents/quickstart.md'}, page_content='Quickstart'),
#  Document(id='doc_5d84e7bf_397', metadata={'url': 'https://docs.langchain.com/oss/python/deepagents/subagents.md'}, page_content='Subagents'),
#  Document(id='doc_b75e8adc_398', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/chat/index.md'}, page_content='Chat models'),
#  Document(id='doc_ed0b8b7a_399', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/document_loaders/index.md'}, page_content='null'),
#  Document(id='doc_37b3305f_400', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/all_providers.md'}, page_content='All integration providers'),
#  Document(id='doc_b0278152_401', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/anthropic.md'}, page_content='Anthropic (Claude)'),
#  Document(id='doc_163b37a1_402', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/aws.md'}, page_content='AWS (Amazon)'),
#  Document(id='doc_41094824_403', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/google.md'}, page_content='Google'),
#  Document(id='doc_c8c9d234_404', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/huggingface.md'}, page_content='Hugging Face'),
#  Document(id='doc_ca82c357_405', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/microsoft.md'}, page_content='Microsoft'),
#  Document(id='doc_1de8a09d_406', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/ollama.md'}, page_content='Ollama'),
#  Document(id='doc_8808e3cb_407', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/openai.md'}, page_content='OpenAI'),
#  Document(id='doc_82396934_408', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/providers/overview.md'}, page_content='Integration packages'),
#  Document(id='doc_e87b3200_409', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/retrievers/index.md'}, page_content='Retrievers'),
#  Document(id='doc_1b095bb8_410', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/splitters/index.md'}, page_content='Text splitters'),
#  Document(id='doc_170d3f89_411', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/stores/index.md'}, page_content='Key-value stores'),
#  Document(id='doc_ac874e2b_412', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/text_embedding/index.md'}, page_content='Embedding models'),
#  Document(id='doc_96355ec4_413', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/tools/index.md'}, page_content='Tools and toolkits'),
#  Document(id='doc_6d99c26c_414', metadata={'url': 'https://docs.langchain.com/oss/python/integrations/vectorstores/index.md'}, page_content='Vector stores'),
#  Document(id='doc_b3a21528_415', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/academy.md'}, page_content='LangChain Academy'),
#  Document(id='doc_2a6b9525_416', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/agents.md'}, page_content='Agents'),
#  Document(id='doc_281c4864_417', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/context-engineering.md'}, page_content='Context engineering in agents'),
#  Document(id='doc_c92ebc45_418', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/deploy.md'}, page_content='Deploy'),
#  Document(id='doc_43f0a69e_419', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/INVALID_PROMPT_INPUT.md'}, page_content='INVALID_PROMPT_INPUT'),
#  Document(id='doc_1a78c89a_420', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/INVALID_TOOL_RESULTS.md'}, page_content='INVALID_TOOL_RESULTS'),
#  Document(id='doc_a11b274c_421', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/MESSAGE_COERCION_FAILURE.md'}, page_content='MESSAGE_COERCION_FAILURE'),
#  Document(id='doc_bb4da0f2_422', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/MODEL_AUTHENTICATION.md'}, page_content='MODEL_AUTHENTICATION'),
#  Document(id='doc_0e003d09_423', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/MODEL_NOT_FOUND.md'}, page_content='MODEL_NOT_FOUND'),
#  Document(id='doc_085486ca_424', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/MODEL_RATE_LIMIT.md'}, page_content='MODEL_RATE_LIMIT'),
#  Document(id='doc_29bef075_425', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE.md'}, page_content='OUTPUT_PARSING_FAILURE'),
#  Document(id='doc_e76195c8_426', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/guardrails.md'}, page_content='Guardrails'),
#  Document(id='doc_53eb1004_427', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/human-in-the-loop.md'}, page_content='Human-in-the-loop'),
#  Document(id='doc_5d644d98_428', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/install.md'}, page_content='Install LangChain'),
#  Document(id='doc_5e1fd847_429', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/knowledge-base.md'}, page_content='Build a semantic search engine with LangChain'),
#  Document(id='doc_0761e8f3_430', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/long-term-memory.md'}, page_content='Long-term memory'),
#  Document(id='doc_33aadcf4_431', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/mcp.md'}, page_content='Model Context Protocol (MCP)'),
#  Document(id='doc_450bb615_432', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/messages.md'}, page_content='Messages'),
#  Document(id='doc_b20b6581_433', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/middleware.md'}, page_content='Middleware'),
#  Document(id='doc_2889618a_434', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/models.md'}, page_content='Models'),
#  Document(id='doc_968c4b04_435', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/multi-agent.md'}, page_content='Multi-agent'),
#  Document(id='doc_2590f46b_436', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/observability.md'}, page_content='Observability'),
#  Document(id='doc_6cb494b1_437', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/overview.md'}, page_content='LangChain overview'),
#  Document(id='doc_15a1fe8b_438', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/philosophy.md'}, page_content='Philosophy'),
#  Document(id='doc_2050f244_439', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/quickstart.md'}, page_content='Quickstart'),
#  Document(id='doc_c6cc6065_440', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/rag.md'}, page_content='Build a RAG agent with LangChain'),
#  Document(id='doc_4f1dfbca_441', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/retrieval.md'}, page_content='Retrieval'),
#  Document(id='doc_289e0cb9_442', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/runtime.md'}, page_content='Runtime'),
#  Document(id='doc_df86229c_443', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/short-term-memory.md'}, page_content='Short-term memory'),
#  Document(id='doc_b3d3454c_444', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/sql-agent.md'}, page_content='Build a SQL agent'),
#  Document(id='doc_e736f54a_445', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/streaming.md'}, page_content='Streaming'),
#  Document(id='doc_b39b6c65_446', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/structured-output.md'}, page_content='Structured output'),
#  Document(id='doc_e20e4b78_447', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/studio.md'}, page_content='Studio'),
#  Document(id='doc_dd6b5441_448', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/supervisor.md'}, page_content='Build a supervisor agent'),
#  Document(id='doc_81312436_449', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/test.md'}, page_content='Test'),
#  Document(id='doc_4d07f354_450', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/tools.md'}, page_content='Tools'),
#  Document(id='doc_73d1c33b_451', metadata={'url': 'https://docs.langchain.com/oss/python/langchain/ui.md'}, page_content='Agent Chat UI'),
#  Document(id='doc_b0eedbfc_452', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/add-memory.md'}, page_content='Memory'),
#  Document(id='doc_cb9e2232_453', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/agentic-rag.md'}, page_content='Build a custom RAG agent'),
#  Document(id='doc_01832075_454', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/application-structure.md'}, page_content='Application structure'),
#  Document(id='doc_8cbaac18_455', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/case-studies.md'}, page_content='Case studies'),
#  Document(id='doc_38d46747_456', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/deploy.md'}, page_content='Deploy'),
#  Document(id='doc_39929d5a_457', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/durable-execution.md'}, page_content='Durable execution'),
#  Document(id='doc_f9d43e90_458', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/GRAPH_RECURSION_LIMIT.md'}, page_content='GRAPH_RECURSION_LIMIT'),
#  Document(id='doc_a60dc9fb_459', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CHAT_HISTORY.md'}, page_content='INVALID_CHAT_HISTORY'),
#  Document(id='doc_f043d4e8_460', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE.md'}, page_content='INVALID_CONCURRENT_GRAPH_UPDATE'),
#  Document(id='doc_961443d4_461', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/INVALID_GRAPH_NODE_RETURN_VALUE.md'}, page_content='INVALID_GRAPH_NODE_RETURN_VALUE'),
#  Document(id='doc_adae33de_462', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/MISSING_CHECKPOINTER.md'}, page_content='MISSING_CHECKPOINTER'),
#  Document(id='doc_b0177d70_463', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/errors/MULTIPLE_SUBGRAPHS.md'}, page_content='MULTIPLE_SUBGRAPHS'),
#  Document(id='doc_b37caeef_464', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/functional-api.md'}, page_content='Functional API overview'),
#  Document(id='doc_7bbf8757_465', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/graph-api.md'}, page_content='Graph API overview'),
#  Document(id='doc_9717fdf0_466', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/install.md'}, page_content='Install LangGraph'),
#  Document(id='doc_2aad7487_467', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/interrupts.md'}, page_content='Interrupts'),
#  Document(id='doc_def3a41c_468', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/local-server.md'}, page_content='Run a local server'),
#  Document(id='doc_41b4840a_469', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/observability.md'}, page_content='Observability'),
#  Document(id='doc_f21dec73_470', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/overview.md'}, page_content='LangGraph overview'),
#  Document(id='doc_b054d00a_471', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/persistence.md'}, page_content='Persistence'),
#  Document(id='doc_a57dcc4e_472', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/pregel.md'}, page_content='LangGraph runtime'),
#  Document(id='doc_f7d76ac9_473', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/quickstart.md'}, page_content='Quickstart'),
#  Document(id='doc_5660f6e2_474', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/sql-agent.md'}, page_content='Build a custom SQL agent'),
#  Document(id='doc_5c7bcc1f_475', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/streaming.md'}, page_content='Streaming'),
#  Document(id='doc_053250cf_476', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/studio.md'}, page_content='Studio'),
#  Document(id='doc_c4bae15c_477', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/test.md'}, page_content='Test'),
#  Document(id='doc_268092f9_478', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/thinking-in-langgraph.md'}, page_content='Thinking in LangGraph'),
#  Document(id='doc_63538235_479', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/ui.md'}, page_content='Agent Chat UI'),
#  Document(id='doc_168c501c_480', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/use-functional-api.md'}, page_content='Use the functional API'),
#  Document(id='doc_fb8c209a_481', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/use-graph-api.md'}, page_content='Use the graph API'),
#  Document(id='doc_6ab77761_482', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/use-subgraphs.md'}, page_content='Subgraphs'),
#  Document(id='doc_2605d38e_483', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/use-time-travel.md'}, page_content='Use time-travel'),
#  Document(id='doc_3722535f_484', metadata={'url': 'https://docs.langchain.com/oss/python/langgraph/workflows-agents.md'}, page_content='Workflows and agents'),
#  Document(id='doc_b82292df_485', metadata={'url': 'https://docs.langchain.com/oss/python/learn.md'}, page_content='Learn'),
#  Document(id='doc_4508d6ea_486', metadata={'url': 'https://docs.langchain.com/oss/python/migrate/langchain-v1.md'}, page_content='LangChain v1 migration guide'),
#  Document(id='doc_cffd62be_487', metadata={'url': 'https://docs.langchain.com/oss/python/migrate/langgraph-v1.md'}, page_content='LangGraph v1 migration guide'),
#  Document(id='doc_d1b87693_488', metadata={'url': 'https://docs.langchain.com/oss/python/reference/deepagents-python.md'}, page_content='Deep Agents'),
#  Document(id='doc_ddd58668_489', metadata={'url': 'https://docs.langchain.com/oss/python/reference/integrations-python.md'}, page_content='Integrations'),
#  Document(id='doc_68653de8_490', metadata={'url': 'https://docs.langchain.com/oss/python/reference/langchain-python.md'}, page_content='LangChain SDK'),
#  Document(id='doc_d240fd24_491', metadata={'url': 'https://docs.langchain.com/oss/python/reference/langgraph-python.md'}, page_content='LangGraph SDK'),
#  Document(id='doc_b3346120_492', metadata={'url': 'https://docs.langchain.com/oss/python/reference/overview.md'}, page_content='Reference'),
#  Document(id='doc_7ee7265b_493', metadata={'url': 'https://docs.langchain.com/oss/python/release-policy.md'}, page_content='Release policy'),
#  Document(id='doc_7e9ffe90_494', metadata={'url': 'https://docs.langchain.com/oss/python/releases/langchain-v1.md'}, page_content="What's new in v1"),
#  Document(id='doc_ad6b979d_495', metadata={'url': 'https://docs.langchain.com/oss/python/releases/langgraph-v1.md'}, page_content="What's new in v1"),
#  Document(id='doc_d97c56ed_496', metadata={'url': 'https://docs.langchain.com/oss/python/security-policy.md'}, page_content='Security policy'),
#  Document(id='doc_9996dfda_497', metadata={'url': 'https://docs.langchain.com/oss/python/versioning.md'}, page_content='Versioning')]

# %%
import chromadb

client = chromadb.Client()
collection = client.get_or_create_collection("sample")

for doc in document_structures:
    collection.add(
        ids=doc.id,
        documents=doc.page_content,
        metadatas=doc.metadata
    )

# %%
collection.count()
# Out:
# 498

# %%
collection.peek()
# Out:
# {'ids': ['doc_aec5eb07_0',
#   'doc_c0865835_1',
#   'doc_1b4741a8_2',
#   'doc_6f7e215f_3',
#   'doc_ff7b3ddf_4',
#   'doc_bb4e7970_5',
#   'doc_fe1c6b0f_6',
#   'doc_1a56c9be_7',
#   'doc_3dd8fc29_8',
#   'doc_ce5a8f3a_9'],
#  'embeddings': array([[ 0.03034231,  0.09264877, -0.0748743 , ..., -0.04384101,
#          -0.03221784,  0.00014146],
#         [-0.08304433,  0.01736081, -0.00843294, ..., -0.03126846,
#           0.10851631, -0.03250459],
#         [-0.07311932,  0.03917663, -0.10074075, ...,  0.03521687,
#          -0.00917505, -0.04572854],
#         ...,
#         [-0.01138952, -0.02653145, -0.08392476, ...,  0.03865344,
#           0.02316016, -0.01675651],
#         [-0.08117197, -0.04342891, -0.04244822, ..., -0.050323  ,
#           0.1169309 ,  0.05921618],
#         [-0.06853037,  0.01133358,  0.05638402, ...,  0.02734672,
#          -0.00561612, -0.03183711]], shape=(10, 384)),
#  'documents': ['null',
#   'Connect an authentication provider',
#   'Human-in-the-loop using server API',
#   'Add metadata and tags to traces',
#   'Overview',
#   'Set up Agent Auth (Beta)',
#   'Agent Builder',
#   'Agent Builder setup',
#   'Supported tools',
#   'Alerts in LangSmith'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'url': 'https://docs.langchain.com/index.md'},
#   {'url': 'https://docs.langchain.com/langsmith/add-auth-server.md'},
#   {'url': 'https://docs.langchain.com/langsmith/add-human-in-the-loop.md'},
#   {'url': 'https://docs.langchain.com/langsmith/add-metadata-tags.md'},
#   {'url': 'https://docs.langchain.com/langsmith/administration-overview.md'},
#   {'url': 'https://docs.langchain.com/langsmith/agent-auth.md'},
#   {'url': 'https://docs.langchain.com/langsmith/agent-builder.md'},
#   {'url': 'https://docs.langchain.com/langsmith/agent-builder-setup.md'},
#   {'url': 'https://docs.langchain.com/langsmith/agent-builder-tools.md'},
#   {'url': 'https://docs.langchain.com/langsmith/alerts.md'}]}

# %%
query_result_topic = collection.query(query_texts="Langsmith collector proxy",n_results=3)

# %%
query_result_topic
# Out:
# {'ids': [['doc_452d0a35_31', 'doc_13fc4f9d_110', 'doc_2dcd252a_208']],
#  'embeddings': None,
#  'documents': [['Beta LangSmith Collector-Proxy',
#    'Configure your collector for LangSmith telemetry',
#    'LangSmith API reference']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://docs.langchain.com/langsmith/collector-proxy.md'},
#    {'url': 'https://docs.langchain.com/langsmith/langsmith-collector.md'},
#    {'url': 'https://docs.langchain.com/langsmith/smith-api-ref.md'}]],
#  'distances': [[0.22020037472248077, 0.6293209791183472, 0.6580455303192139]]}

# %%
retrieved_docs = []

if query_result_topic['documents'] and query_result_topic['documents'][0]:
    documents = query_result_topic['documents'][0]
    metadatas = query_result_topic['metadatas'][0]
    distances = query_result_topic['distances'][0]
    ids = query_result_topic['ids'][0]

    for i,(doc_id,document,metadata,distance) in enumerate(zip(ids,documents,metadatas,distances)):
        similarity_score = 1- distance

        if similarity_score >= 0.5:
            retrieved_docs.append({
                'doc_id':doc_id,
                'topic':document,
                'url':metadata.get('url'),
                'similarity_score':similarity_score,
                'distance':distance,
                'rank':i+1
            })

    print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
else: 
    print("No documents found")
# Out:
# Retrieved 1 documents (after filtering)

# %%
retrieved_docs
# Out:
# [{'doc_id': 'doc_452d0a35_31',
#   'topic': 'Beta LangSmith Collector-Proxy',
#   'url': 'https://docs.langchain.com/langsmith/collector-proxy.md',
#   'similarity_score': 0.7797996252775192,
#   'distance': 0.22020037472248077,
#   'rank': 1}]
